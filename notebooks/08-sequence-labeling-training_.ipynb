# %% [markdown]
# Notebook prepared by Henrique Lopes Cardoso (hlc@fe.up.pt), based on [Named Entity Recognition and Classification with Scikit-Learn](https://www.kdnuggets.com/2018/10/named-entity-recognition-classification-scikit-learn.html) by Susan Li.
#
# # SEQUENCE LABELING TRAINING

# %% [markdown]
# ## Training a NER model
#
# To train a model on NER, we need to rely on an annotated dataset. For the purpose of this notebook, we'll use the [Annotated Corpus for Named Entity Recognition](https://www.kaggle.com/abhinavwalia95/entity-annotated-corpus), which has been annotated with POS and named entities, using BIO encoding.
#
# This is what the dataset (a CSV file) looks like:
#
# ![ner_dataset_screenshot.png](attachment:ner_dataset_screenshot.png)

# %% [markdown]
# Let's load the data and have a look on it.

# %%
import pandas as pd

# loading NER data
df = pd.read_csv("../data/ner_dataset.csv", encoding="ISO-8859-1")

df.head()
# Out:
#     Sentence #           Word  POS Tag
# 0  Sentence: 1      Thousands  NNS   O
# 1          NaN             of   IN   O
# 2          NaN  demonstrators  NNS   O
# 3          NaN           have  VBP   O
# 4          NaN        marched  VBN   O

# %% [markdown]
# There are several rows for which the first column (_Sentence #_) is _NaN_. This is because only the first token in each sentence is signaled with the sentence number.
#
# How many *NaN*s are there?

# %%
# your code here
df["Sentence #"].isna().sum()
# Out:
# 1000616

# %% [markdown]
# We could choose to get rid of that first column. However, for reasons that will later become evident, we'll fill down the sentence number to all tokens in each sentence.

# %%
df = df.fillna(method="ffill")
df[:25]
# Out:
#      Sentence #           Word  POS    Tag
# 0   Sentence: 1      Thousands  NNS      O
# 1   Sentence: 1             of   IN      O
# 2   Sentence: 1  demonstrators  NNS      O
# 3   Sentence: 1           have  VBP      O
# 4   Sentence: 1        marched  VBN      O
# 5   Sentence: 1        through   IN      O
# 6   Sentence: 1         London  NNP  B-geo
# 7   Sentence: 1             to   TO      O
# 8   Sentence: 1        protest   VB      O
# 9   Sentence: 1            the   DT      O
# 10  Sentence: 1            war   NN      O
# 11  Sentence: 1             in   IN      O
# 12  Sentence: 1           Iraq  NNP  B-geo
# 13  Sentence: 1            and   CC      O
# 14  Sentence: 1         demand   VB      O
# 15  Sentence: 1            the   DT      O
# 16  Sentence: 1     withdrawal   NN      O
# 17  Sentence: 1             of   IN      O
# 18  Sentence: 1        British   JJ  B-gpe
# 19  Sentence: 1         troops  NNS      O
# 20  Sentence: 1           from   IN      O
# 21  Sentence: 1           that   DT      O
# 22  Sentence: 1        country   NN      O
# 23  Sentence: 1              .    .      O
# 24  Sentence: 2       Families  NNS      O

# %% [markdown]
# Let's see now how many sentences we've got:

# %%
df["Sentence #"].nunique()
# Out:
# 47959

# %% [markdown]
# How many words, POS and BIO tags are there?

# %%
# your code here
df["Word"].nunique(), df["POS"].nunique(), df["Tag"].nunique()
# Out:
# (35178, 42, 17)

# %% [markdown]
# Let's check the distribution of POS tags:

# %%
df.groupby("POS").size().reset_index(name="counts")
# Out:
#      POS  counts
# 0      $    1149
# 1      ,   32757
# 2      .   47831
# 3      :     795
# 4      ;     214
# 5     CC   23716
# 6     CD   24695
# 7     DT   98454
# 8     EX     663
# 9     FW       1
# 10    IN  120996
# 11    JJ   78412
# 12   JJR    2967
# 13   JJS    3034
# 14   LRB     678
# 15    MD    6973
# 16    NN  145807
# 17   NNP  131426
# 18  NNPS    2521
# 19   NNS   75840
# 20   PDT     147
# 21   POS   11257
# 22   PRP   13318
# 23  PRP$    8655
# 24    RB   20252
# 25   RBR    1055
# 26   RBS     296
# 27    RP    2490
# 28   RRB     679
# 29    TO   23061
# 30    UH      24
# 31    VB   24211
# 32   VBD   39379
# 33   VBG   19125
# 34   VBN   32328
# 35   VBP   16158
# 36   VBZ   24960
# 37   WDT    3698
# 38    WP    2542
# 39   WP$      99
# 40   WRB    2184
# 41    ``    3728

# %% [markdown]
# What is the distribution of named entity BIO tags?

# %%
# your code here
df.groupby("Tag").size().reset_index(name="counts")
# Out:
#       Tag  counts
# 0   B-art     402
# 1   B-eve     308
# 2   B-geo   37644
# 3   B-gpe   15870
# 4   B-nat     201
# 5   B-org   20143
# 6   B-per   16990
# 7   B-tim   20333
# 8   I-art     297
# 9   I-eve     253
# 10  I-geo    7414
# 11  I-gpe     198
# 12  I-nat      51
# 13  I-org   16784
# 14  I-per   17251
# 15  I-tim    6528
# 16      O  887908

# %% [markdown]
# As expected, we have a very unbalanced dataset in terms of NER tags. Which is the most prevalent named entity type? What types tend to be composed of a single word?

# %% [markdown]
# ### Can we do it with "traditional" classifiers?

# %% [markdown]
# First we generate our dataset for training the NER model. Adding the POS tag to the word seems to be a good idea -- hopefully the word's POS is helpful to determine whether the word corresponds to a named entity. We can get rid of the sentence number, though, as it does not seem to add anything useful for the task.

# %%
X = df[["Word", "POS"]]

# %% [markdown]
# Let's also collect the BIO labels for the words:

# %%
y = df["Tag"].values

# %% [markdown]
# Let's check the shape of our feature matrix:

# %%
print(X.shape)
print(y.shape)
# Out:
# (1048575, 2)
# (1048575,)

# %% [markdown]
# We need to transform each data entry into a 1-hot vector, for which we can use [DictVectorizer](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.DictVectorizer.html). This will create a table with as many columns as the number of unique words and POS tags we have in our dataset -- the features we'll use to represent each token of the text.

# %%
from sklearn.feature_extraction import DictVectorizer

# sparse=False will use much more memory, and take much longer to train
v = DictVectorizer(sparse=True)
v.fit(X.to_dict("records"))
# Out:
# DictVectorizer()

# %% [markdown]
# Now we split the dataset into training and test sets (we should be more careful by obtaining a test set that starts at the beginning of a sentence, but let's disregard this for now):

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.10, random_state=0, stratify=y)

# %% [markdown]
# If the full data set is too big to fit into memory, we'll need to use mini-batches of data to train the model with an [out-of-core learning](https://scikit-learn.org/0.15/modules/scaling_strategies.html) algorithm.
#
# Try training a traditional classifier, such as MultinomialNB. How well does it perform?

# %%
# your code here
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import f1_score

clf = MultinomialNB()
clf.fit(v.transform(X_train.to_dict('records')), y_train)
print(f"score: {clf.score(v.transform(X_test.to_dict('records')), y_test)}")
print(f"f1-score: {f1_score(y_test, clf.predict(v.transform(X_test.to_dict('records'))), average='macro')}")
# Out:
# score: 0.9420263594575521
# f1-score: 0.38728530075083123

# %% [markdown]
# The model seems to have a good accuracy, but that's too misleading -- the dataset is very unbalanced, with many _O_ (outside) labels. If we look at macro average f1-score, we observe unsatisfactory results.
#
# Try out other classifiers, namely those that support [out-of-core](https://scikit-learn.org/0.15/modules/scaling_strategies.html) learning, such as:
#
# - Perceptron
# - SGDClassifier
# - PassiveAggressiveClassifier

# %%
# your code here
from sklearn.linear_model import Perceptron, SGDClassifier, PassiveAggressiveClassifier

clfs = [
    Perceptron(),
    SGDClassifier(),
    PassiveAggressiveClassifier()
]

X_train_transf = v.transform(X_train.to_dict('records'))
X_test_transf = v.transform(X_test.to_dict('records'))

for clf in clfs:
    clf.fit(X_train_transf, y_train)

    print(f"{clf.__class__.__name__}\n")
    print(f"Score: {clf.score(X_test_transf, y_test)}")
    print(f"F1 Score: {f1_score(y_test, clf.predict(X_test_transf), average='macro')}\n")
# Out:
# Perceptron
#
# score: 0.9055389193003872
# f1-score: 0.41043932003118005
#
# SGDClassifier
#
# score: 0.9439241641076503
# f1-score: 0.4478641025677522
#
# PassiveAggressiveClassifier
#
# score: 0.9449064449064449
# f1-score: 0.4627161007491362

# %% [markdown]
# Turning to classifiers tailored for sequence labeling tasks!

# %% [markdown]
# ### Conditional Random Fields
#
# Conditional Random Fields is one of the most well known algorithms for dealing with sequential data, and is very useful for sequence labeling tasks.
# We will make use of [sklearn-crfsuite](https://sklearn-crfsuite.readthedocs.io/en/latest/), which implements a CRF classifier.

# %% [markdown]
# #### Splitting into sentences
#
# Let's first reconstruct the sentences with their POS and NER tags:

# %%
class SentenceGetter(object):
    def __init__(self, data):
        self.n_sent = 1
        self.data = data
        self.empty = False
        agg_func = lambda s: [
            (w, p, t)
            for w, p, t in zip(
                s["Word"].values.tolist(),
                s["POS"].values.tolist(),
                s["Tag"].values.tolist(),
            )
        ]
        self.grouped = self.data.groupby("Sentence #").apply(agg_func)
        self.sentences = [s for s in self.grouped]

    def get_next(self):
        try:
            s = self.grouped["Sentence: {}".format(self.n_sent)]
            self.n_sent += 1
            return s
        except:
            return None


sentences = SentenceGetter(df).sentences

# %%
sentences
# Out:
# [[('Thousands', 'NNS', 'O'),
#   ('of', 'IN', 'O'),
#   ('demonstrators', 'NNS', 'O'),
#   ('have', 'VBP', 'O'),
#   ('marched', 'VBN', 'O'),
#   ('through', 'IN', 'O'),
#   ('London', 'NNP', 'B-geo'),
#   ('to', 'TO', 'O'),
#   ('protest', 'VB', 'O'),
#   ('the', 'DT', 'O'),
#   ('war', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('Iraq', 'NNP', 'B-geo'),
#   ('and', 'CC', 'O'),
#   ('demand', 'VB', 'O'),
#   ('the', 'DT', 'O'),
#   ('withdrawal', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('British', 'JJ', 'B-gpe'),
#   ('troops', 'NNS', 'O'),
#   ('from', 'IN', 'O'),
#   ('that', 'DT', 'O'),
#   ('country', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Iranian', 'JJ', 'B-gpe'),
#   ('officials', 'NNS', 'O'),
#   ('say', 'VBP', 'O'),
#   ('they', 'PRP', 'O'),
#   ('expect', 'VBP', 'O'),
#   ('to', 'TO', 'O'),
#   ('get', 'VB', 'O'),
#   ('access', 'NN', 'O'),
#   ('to', 'TO', 'O'),
#   ('sealed', 'JJ', 'O'),
#   ('sensitive', 'JJ', 'O'),
#   ('parts', 'NNS', 'O'),
#   ('of', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('plant', 'NN', 'O'),
#   ('Wednesday', 'NNP', 'B-tim'),
#   (',', ',', 'O'),
#   ('after', 'IN', 'O'),
#   ('an', 'DT', 'O'),
#   ('IAEA', 'NNP', 'B-org'),
#   ('surveillance', 'NN', 'O'),
#   ('system', 'NN', 'O'),
#   ('begins', 'VBZ', 'O'),
#   ('functioning', 'VBG', 'O'),
#   ('.', '.', 'O')],
#  [('Helicopter', 'NN', 'O'),
#   ('gunships', 'NNS', 'O'),
#   ('Saturday', 'NNP', 'B-tim'),
#   ('pounded', 'VBD', 'O'),
#   ('militant', 'JJ', 'O'),
#   ('hideouts', 'NNS', 'O'),
#   ('in', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('Orakzai', 'NNP', 'B-geo'),
#   ('tribal', 'JJ', 'O'),
#   ('region', 'NN', 'O'),
#   (',', ',', 'O'),
#   ('where', 'WRB', 'O'),
#   ('many', 'JJ', 'O'),
#   ('Taliban', 'NNP', 'B-org'),
#   ('militants', 'NNS', 'O'),
#   ('are', 'VBP', 'O'),
#   ('believed', 'VBN', 'O'),
#   ('to', 'TO', 'O'),
#   ('have', 'VB', 'O'),
#   ('fled', 'VBN', 'O'),
#   ('to', 'TO', 'O'),
#   ('avoid', 'VB', 'O'),
#   ('an', 'DT', 'O'),
#   ('earlier', 'JJR', 'O'),
#   ('military', 'JJ', 'O'),
#   ('offensive', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('nearby', 'JJ', 'O'),
#   ('South', 'NNP', 'B-geo'),
#   ('Waziristan', 'NNP', 'I-geo'),
#   ('.', '.', 'O')],
#  [('They', 'PRP', 'O'),
#   ('left', 'VBD', 'O'),
#   ('after', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('tense', 'NN', 'O'),
#   ('hour-long', 'JJ', 'O'),
#   ('standoff', 'NN', 'O'),
#   ('with', 'IN', 'O'),
#   ('riot', 'NN', 'O'),
#   ('police', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('U.N.', 'NNP', 'B-geo'),
#   ('relief', 'NN', 'O'),
#   ('coordinator', 'NN', 'O'),
#   ('Jan', 'NNP', 'B-per'),
#   ('Egeland', 'NNP', 'I-per'),
#   ('said', 'VBD', 'O'),
#   ('Sunday', 'NNP', 'B-tim'),
#   (',', ',', 'O'),
#   ('U.S.', 'NNP', 'B-geo'),
#   (',', ',', 'O'),
#   ('Indonesian', 'JJ', 'B-gpe'),
#   ('and', 'CC', 'O'),
#   ('Australian', 'JJ', 'B-gpe'),
#   ('military', 'JJ', 'O'),
#   ('helicopters', 'NNS', 'O'),
#   ('are', 'VBP', 'O'),
#   ('ferrying', 'VBG', 'O'),
#   ('out', 'RP', 'O'),
#   ('food', 'NN', 'O'),
#   ('and', 'CC', 'O'),
#   ('supplies', 'NNS', 'O'),
#   ('to', 'TO', 'O'),
#   ('remote', 'VB', 'O'),
#   ('areas', 'NNS', 'O'),
#   ('of', 'IN', 'O'),
#   ('western', 'JJ', 'O'),
#   ('Aceh', 'NNP', 'B-geo'),
#   ('province', 'NN', 'O'),
#   ('that', 'IN', 'O'),
#   ('ground', 'NN', 'O'),
#   ('crews', 'NNS', 'O'),
#   ('can', 'MD', 'O'),
#   ('not', 'RB', 'O'),
#   ('reach', 'VB', 'O'),
#   ('.', '.', 'O')],
#  [('Mr.', 'NNP', 'B-per'),
#   ('Egeland', 'NNP', 'I-per'),
#   ('said', 'VBD', 'O'),
#   ('the', 'DT', 'O'),
#   ('latest', 'JJS', 'O'),
#   ('figures', 'NNS', 'O'),
#   ('show', 'VBP', 'O'),
#   ('1.8', 'CD', 'O'),
#   ('million', 'CD', 'O'),
#   ('people', 'NNS', 'O'),
#   ('are', 'VBP', 'O'),
#   ('in', 'IN', 'O'),
#   ('need', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('food', 'NN', 'O'),
#   ('assistance', 'NN', 'O'),
#   ('-', ':', 'O'),
#   ('with', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('need', 'NN', 'O'),
#   ('greatest', 'JJS', 'O'),
#   ('in', 'IN', 'O'),
#   ('Indonesia', 'NNP', 'B-tim'),
#   (',', ',', 'O'),
#   ('Sri', 'NNP', 'B-per'),
#   ('Lanka', 'NNP', 'B-gpe'),
#   (',', ',', 'O'),
#   ('the', 'DT', 'O'),
#   ('Maldives', 'NNP', 'B-geo'),
#   ('and', 'CC', 'O'),
#   ('India', 'NNP', 'B-geo'),
#   ('.', '.', 'O')],
#  [('He', 'PRP', 'O'),
#   ('said', 'VBD', 'O'),
#   ('last', 'JJ', 'O'),
#   ('week', 'NN', 'O'),
#   ("'s", 'POS', 'O'),
#   ('tsunami', 'NN', 'O'),
#   ('and', 'CC', 'O'),
#   ('the', 'DT', 'O'),
#   ('massive', 'JJ', 'O'),
#   ('underwater', 'NN', 'O'),
#   ('earthquake', 'NN', 'O'),
#   ('that', 'WDT', 'O'),
#   ('triggered', 'VBD', 'O'),
#   ('it', 'PRP', 'O'),
#   ('has', 'VBZ', 'O'),
#   ('affected', 'VBN', 'O'),
#   ('millions', 'NNS', 'O'),
#   ('in', 'IN', 'O'),
#   ('Asia', 'NNP', 'B-geo'),
#   ('and', 'CC', 'O'),
#   ('Africa', 'NNP', 'B-geo'),
#   ('.', '.', 'O')],
#  [('Some', 'DT', 'O'),
#   ('1,27,000', 'CD', 'O'),
#   ('people', 'NNS', 'O'),
#   ('are', 'VBP', 'O'),
#   ('known', 'VBN', 'O'),
#   ('dead', 'JJ', 'O'),
#   ('.', '.', 'O')],
#  [('Aid', 'NNP', 'O'),
#   ('is', 'VBZ', 'O'),
#   ('being', 'VBG', 'O'),
#   ('rushed', 'VBN', 'O'),
#   ('to', 'TO', 'O'),
#   ('the', 'DT', 'O'),
#   ('region', 'NN', 'O'),
#   (',', ',', 'O'),
#   ('but', 'CC', 'O'),
#   ('the', 'DT', 'O'),
#   ('U.N.', 'NNP', 'B-geo'),
#   ('official', 'NN', 'O'),
#   ('stressed', 'VBD', 'O'),
#   ('that', 'IN', 'O'),
#   ('bottlenecks', 'NNS', 'O'),
#   ('and', 'CC', 'O'),
#   ('a', 'DT', 'O'),
#   ('lack', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('infrastructure', 'NN', 'O'),
#   ('remain', 'VBP', 'O'),
#   ('a', 'DT', 'O'),
#   ('challenge', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Lebanese', 'JJ', 'B-gpe'),
#   ('politicians', 'NNS', 'O'),
#   ('are', 'VBP', 'O'),
#   ('condemning', 'VBG', 'O'),
#   ('Friday', 'NNP', 'B-tim'),
#   ("'s", 'POS', 'O'),
#   ('bomb', 'NN', 'O'),
#   ('blast', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('Christian', 'JJ', 'O'),
#   ('neighborhood', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('Beirut', 'NNP', 'B-geo'),
#   ('as', 'IN', 'O'),
#   ('an', 'DT', 'O'),
#   ('attempt', 'NN', 'O'),
#   ('to', 'TO', 'O'),
#   ('sow', 'VB', 'O'),
#   ('sectarian', 'JJ', 'O'),
#   ('strife', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('formerly', 'RB', 'O'),
#   ('war-torn', 'JJ', 'O'),
#   ('country', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('In', 'IN', 'O'),
#   ('Beirut', 'NNP', 'B-geo'),
#   (',', ',', 'O'),
#   ('a', 'DT', 'O'),
#   ('string', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('officials', 'NNS', 'O'),
#   ('voiced', 'VBD', 'O'),
#   ('their', 'PRP$', 'O'),
#   ('anger', 'NN', 'O'),
#   (',', ',', 'O'),
#   ('while', 'IN', 'O'),
#   ('at', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('United', 'NNP', 'B-org'),
#   ('Nations', 'NNP', 'I-org'),
#   ('summit', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('New', 'NNP', 'B-geo'),
#   ('York', 'NNP', 'I-geo'),
#   (',', ',', 'O'),
#   ('Prime', 'NNP', 'B-per'),
#   ('Minister', 'NNP', 'O'),
#   ('Fouad', 'NNP', 'B-per'),
#   ('Siniora', 'NNP', 'I-per'),
#   ('said', 'VBD', 'O'),
#   ('the', 'DT', 'O'),
#   ('Lebanese', 'JJ', 'B-gpe'),
#   ('people', 'NNS', 'O'),
#   ('are', 'VBP', 'O'),
#   ('resolute', 'JJ', 'O'),
#   ('in', 'IN', 'O'),
#   ('preventing', 'VBG', 'O'),
#   ('such', 'JJ', 'O'),
#   ('attempts', 'NNS', 'O'),
#   ('from', 'IN', 'O'),
#   ('destroying', 'VBG', 'O'),
#   ('their', 'PRP$', 'O'),
#   ('spirit', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('One', 'CD', 'O'),
#   ('person', 'NN', 'O'),
#   ('was', 'VBD', 'O'),
#   ('killed', 'VBN', 'O'),
#   ('and', 'CC', 'O'),
#   ('more', 'JJR', 'O'),
#   ('than', 'IN', 'O'),
#   ('20', 'CD', 'O'),
#   ('others', 'NNS', 'O'),
#   ('injured', 'VBN', 'O'),
#   ('in', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('bomb', 'NN', 'O'),
#   ('blast', 'NN', 'O'),
#   ('late', 'JJ', 'O'),
#   ('Friday', 'NNP', 'B-tim'),
#   (',', ',', 'O'),
#   ('which', 'WDT', 'O'),
#   ('took', 'VBD', 'O'),
#   ('place', 'NN', 'O'),
#   ('on', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('residential', 'JJ', 'O'),
#   ('street', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Lebanon', 'NNP', 'B-geo'),
#   ('has', 'VBZ', 'O'),
#   ('suffered', 'VBN', 'O'),
#   ('a', 'DT', 'O'),
#   ('series', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('bombings', 'NNS', 'O'),
#   ('since', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('massive', 'JJ', 'O'),
#   ('explosion', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('February', 'NNP', 'B-tim'),
#   ('that', 'WDT', 'O'),
#   ('killed', 'VBD', 'O'),
#   ('former', 'JJ', 'O'),
#   ('Prime', 'NNP', 'B-per'),
#   ('Minister', 'NNP', 'O'),
#   ('Rafik', 'NNP', 'B-per'),
#   ('Hariri', 'NNP', 'I-per'),
#   ('and', 'CC', 'O'),
#   ('20', 'CD', 'O'),
#   ('other', 'JJ', 'O'),
#   ('people', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('Syria', 'NNP', 'B-geo'),
#   ('is', 'VBZ', 'O'),
#   ('widely', 'RB', 'O'),
#   ('accused', 'VBN', 'O'),
#   ('of', 'IN', 'O'),
#   ('involvement', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('his', 'PRP$', 'O'),
#   ('killing', 'NN', 'O'),
#   (',', ',', 'O'),
#   ('and', 'CC', 'O'),
#   ('Friday', 'NNP', 'B-tim'),
#   ("'s", 'POS', 'O'),
#   ('explosion', 'NN', 'O'),
#   ('comes', 'VBZ', 'O'),
#   ('days', 'NNS', 'O'),
#   ('before', 'IN', 'O'),
#   ('U.N.', 'NNP', 'B-geo'),
#   ('investigator', 'NN', 'O'),
#   ('Detlev', 'NNP', 'B-per'),
#   ('Mehlis', 'NNP', 'I-per'),
#   ('is', 'VBZ', 'O'),
#   ('to', 'TO', 'O'),
#   ('return', 'VB', 'O'),
#   ('to', 'TO', 'O'),
#   ('Damascus', 'NNP', 'B-geo'),
#   ('to', 'TO', 'O'),
#   ('interview', 'VB', 'O'),
#   ('several', 'JJ', 'O'),
#   ('Syrian', 'JJ', 'B-gpe'),
#   ('officials', 'NNS', 'O'),
#   ('about', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('assassination', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('global', 'JJ', 'O'),
#   ('financial', 'JJ', 'O'),
#   ('crisis', 'NN', 'O'),
#   ('has', 'VBZ', 'O'),
#   ('left', 'VBN', 'O'),
#   ('Iceland', 'NNP', 'B-org'),
#   ("'s", 'POS', 'O'),
#   ('economy', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('shambles', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('Israeli', 'JJ', 'B-gpe'),
#   ('officials', 'NNS', 'O'),
#   ('say', 'VBP', 'O'),
#   ('Prime', 'NNP', 'B-per'),
#   ('Minister', 'NNP', 'I-per'),
#   ('Ariel', 'NNP', 'I-per'),
#   ('Sharon', 'NNP', 'I-per'),
#   ('will', 'MD', 'O'),
#   ('undergo', 'VB', 'O'),
#   ('a', 'DT', 'O'),
#   ('medical', 'JJ', 'O'),
#   ('procedure', 'NN', 'O'),
#   ('Thursday', 'NNP', 'B-tim'),
#   ('to', 'TO', 'O'),
#   ('close', 'VB', 'O'),
#   ('a', 'DT', 'O'),
#   ('tiny', 'JJ', 'O'),
#   ('hole', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('his', 'PRP$', 'O'),
#   ('heart', 'NN', 'O'),
#   ('discovered', 'VBN', 'O'),
#   ('during', 'IN', 'O'),
#   ('treatment', 'NN', 'O'),
#   ('for', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('minor', 'JJ', 'O'),
#   ('stroke', 'NN', 'O'),
#   ('suffered', 'VBN', 'O'),
#   ('last', 'JJ', 'O'),
#   ('month', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Doctors', 'NNS', 'O'),
#   ('describe', 'VBP', 'O'),
#   ('the', 'DT', 'O'),
#   ('tiny', 'JJ', 'O'),
#   ('hole', 'NN', 'O'),
#   ('as', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('minor', 'JJ', 'O'),
#   ('birth', 'NN', 'O'),
#   ('defect', 'NN', 'O'),
#   ('and', 'CC', 'O'),
#   ('say', 'VB', 'O'),
#   ('it', 'PRP', 'O'),
#   ('is', 'VBZ', 'O'),
#   ('in', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('partition', 'NN', 'O'),
#   ('between', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('upper', 'JJ', 'O'),
#   ('chambers', 'NNS', 'O'),
#   ('of', 'IN', 'O'),
#   ('Mr.', 'NNP', 'B-per'),
#   ('Sharon', 'NNP', 'I-per'),
#   ("'s", 'POS', 'O'),
#   ('heart', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('procedure', 'NN', 'O'),
#   (',', ',', 'O'),
#   ('known', 'VBN', 'O'),
#   ('as', 'IN', 'O'),
#   ('cardiac', 'JJ', 'O'),
#   ('catheterization', 'NN', 'O'),
#   (',', ',', 'O'),
#   ('involves', 'VBZ', 'O'),
#   ('inserting', 'VBG', 'O'),
#   ('a', 'DT', 'O'),
#   ('catheter', 'NN', 'O'),
#   ('through', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('blood', 'NN', 'O'),
#   ('vessel', 'NN', 'O'),
#   ('into', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('heart', 'NN', 'O'),
#   (',', ',', 'O'),
#   ('where', 'WRB', 'O'),
#   ('an', 'DT', 'O'),
#   ('umbrella-like', 'JJ', 'O'),
#   ('device', 'NN', 'O'),
#   ('will', 'MD', 'O'),
#   ('plug', 'VB', 'O'),
#   ('the', 'DT', 'O'),
#   ('hole', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Doctors', 'NNS', 'O'),
#   ('say', 'VBP', 'O'),
#   ('they', 'PRP', 'O'),
#   ('expect', 'VBP', 'O'),
#   ('Mr.', 'NNP', 'B-per'),
#   ('Sharon', 'NNP', 'I-per'),
#   ('will', 'MD', 'O'),
#   ('make', 'VB', 'O'),
#   ('a', 'DT', 'O'),
#   ('full', 'JJ', 'O'),
#   ('recovery', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Mr.', 'NNP', 'B-per'),
#   ('Sharon', 'NNP', 'I-per'),
#   ('returned', 'VBD', 'O'),
#   ('to', 'TO', 'O'),
#   ('work', 'VB', 'O'),
#   ('on', 'IN', 'O'),
#   ('December', 'NNP', 'B-tim'),
#   ('25', 'CD', 'I-tim'),
#   (',', ',', 'O'),
#   ('one', 'CD', 'B-tim'),
#   ('week', 'NN', 'O'),
#   ('after', 'IN', 'O'),
#   ('his', 'PRP$', 'O'),
#   ('emergency', 'NN', 'O'),
#   ('hospitalization', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Doctors', 'NNS', 'O'),
#   ('say', 'VBP', 'O'),
#   ('the', 'DT', 'O'),
#   ('stroke', 'NN', 'O'),
#   ('has', 'VBZ', 'O'),
#   ('not', 'RB', 'O'),
#   ('caused', 'VBN', 'O'),
#   ('any', 'DT', 'O'),
#   ('permanent', 'JJ', 'O'),
#   ('damage', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('designers', 'NNS', 'O'),
#   ('of', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('first', 'JJ', 'O'),
#   ('private', 'JJ', 'O'),
#   ('manned', 'VBN', 'O'),
#   ('rocket', 'NN', 'O'),
#   ('to', 'TO', 'O'),
#   ('burst', 'VB', 'O'),
#   ('into', 'IN', 'O'),
#   ('space', 'NN', 'O'),
#   ('have', 'VBP', 'O'),
#   ('received', 'VBN', 'O'),
#   ('a', 'DT', 'O'),
#   ('$', '$', 'O'),
#   ('10', 'CD', 'O'),
#   ('million', 'CD', 'O'),
#   ('prize', 'NN', 'O'),
#   ('created', 'VBN', 'O'),
#   ('to', 'TO', 'O'),
#   ('promote', 'VB', 'O'),
#   ('space', 'NN', 'O'),
#   ('tourism', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('SpaceShipOne', 'NNP', 'B-art'),
#   ('designer', 'NN', 'O'),
#   ('Burt', 'NNP', 'B-per'),
#   ('Rutan', 'NNP', 'I-per'),
#   ('accepted', 'VBD', 'O'),
#   ('the', 'DT', 'O'),
#   ('Ansari', 'NNP', 'B-art'),
#   ('X', 'NNP', 'I-art'),
#   ('Prize', 'NNP', 'I-art'),
#   ('money', 'NN', 'O'),
#   ('and', 'CC', 'O'),
#   ('a', 'DT', 'O'),
#   ('trophy', 'NN', 'O'),
#   ('on', 'IN', 'O'),
#   ('behalf', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('his', 'PRP$', 'O'),
#   ('team', 'NN', 'O'),
#   ('Saturday', 'NNP', 'B-tim'),
#   ('during', 'IN', 'O'),
#   ('an', 'DT', 'O'),
#   ('awards', 'NNS', 'O'),
#   ('ceremony', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('U.S.', 'NNP', 'B-geo'),
#   ('state', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('Missouri', 'NNP', 'B-geo'),
#   ('.', '.', 'O')],
#  [('To', 'TO', 'O'),
#   ('win', 'VB', 'O'),
#   ('the', 'DT', 'O'),
#   ('money', 'NN', 'O'),
#   (',', ',', 'O'),
#   ('SpaceShipOne', 'NNP', 'B-art'),
#   ('had', 'VBD', 'O'),
#   ('to', 'TO', 'O'),
#   ('blast', 'VB', 'O'),
#   ('off', 'RP', 'O'),
#   ('into', 'IN', 'O'),
#   ('space', 'NN', 'O'),
#   ('twice', 'RB', 'O'),
#   ('in', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('two-week', 'JJ', 'B-tim'),
#   ('period', 'NN', 'I-tim'),
#   ('and', 'CC', 'O'),
#   ('fly', 'VB', 'O'),
#   ('at', 'IN', 'O'),
#   ('least', 'JJS', 'O'),
#   ('100', 'CD', 'O'),
#   ('kilometers', 'NNS', 'O'),
#   ('above', 'IN', 'O'),
#   ('Earth', 'NNP', 'B-geo'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('spacecraft', 'NN', 'O'),
#   ('made', 'VBD', 'O'),
#   ('its', 'PRP$', 'O'),
#   ('flights', 'NNS', 'O'),
#   ('in', 'IN', 'O'),
#   ('late', 'JJ', 'O'),
#   ('September', 'NNP', 'B-tim'),
#   ('and', 'CC', 'O'),
#   ('early', 'JJ', 'O'),
#   ('October', 'NNP', 'B-tim'),
#   (',', ',', 'O'),
#   ('lifting', 'VBG', 'O'),
#   ('off', 'RP', 'O'),
#   ('from', 'IN', 'O'),
#   ('California', 'NNP', 'B-geo'),
#   ("'s", 'POS', 'O'),
#   ('Mojave', 'NNP', 'B-geo'),
#   ('desert', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Three', 'CD', 'O'),
#   ('major', 'JJ', 'O'),
#   ('banks', 'NNS', 'O'),
#   ('have', 'VBP', 'O'),
#   ('collapsed', 'VBN', 'O'),
#   (',', ',', 'O'),
#   ('unemployment', 'NN', 'O'),
#   ('has', 'VBZ', 'O'),
#   ('soared', 'VBN', 'O'),
#   (',', ',', 'O'),
#   ('and', 'CC', 'O'),
#   ('the', 'DT', 'O'),
#   ('value', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('krona', 'NN', 'O'),
#   ('has', 'VBZ', 'O'),
#   ('plunged', 'VBN', 'O'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('vehicle', 'NN', 'O'),
#   ('had', 'VBD', 'O'),
#   ('to', 'TO', 'O'),
#   ('carry', 'VB', 'O'),
#   ('a', 'DT', 'O'),
#   ('pilot', 'NN', 'O'),
#   ('and', 'CC', 'O'),
#   ('weight', 'NN', 'O'),
#   ('equivalent', 'NN', 'O'),
#   ('to', 'TO', 'O'),
#   ('two', 'CD', 'O'),
#   ('passengers', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('SpaceShipOne', 'NNP', 'B-art'),
#   ('was', 'VBD', 'O'),
#   ('financed', 'VBN', 'O'),
#   ('with', 'IN', 'O'),
#   ('more', 'JJR', 'O'),
#   ('than', 'IN', 'O'),
#   ('$', '$', 'O'),
#   ('20', 'CD', 'O'),
#   ('million', 'CD', 'O'),
#   ('from', 'IN', 'O'),
#   ('Paul', 'NNP', 'B-per'),
#   ('Allen', 'NNP', 'I-per'),
#   (',', ',', 'O'),
#   ('a', 'DT', 'O'),
#   ('co-founder', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('Microsoft', 'NNP', 'B-org'),
#   ('Corporation', 'NNP', 'I-org'),
#   ('.', '.', 'O')],
#  [('North', 'NNP', 'B-geo'),
#   ('Korea', 'NNP', 'I-geo'),
#   ('says', 'VBZ', 'O'),
#   ('flooding', 'NN', 'O'),
#   ('caused', 'VBN', 'O'),
#   ('by', 'IN', 'O'),
#   ('last', 'JJ', 'O'),
#   ('week', 'NN', 'O'),
#   ("'s", 'POS', 'O'),
#   ('typhoon', 'NN', 'O'),
#   (',', ',', 'O'),
#   ('Wipha', 'NNP', 'B-per'),
#   (',', ',', 'O'),
#   ('has', 'VBZ', 'O'),
#   ('destroyed', 'VBN', 'O'),
#   ('14,000', 'CD', 'O'),
#   ('homes', 'NNS', 'O'),
#   ('and', 'CC', 'O'),
#   ('1,09,000', 'CD', 'O'),
#   ('hectares', 'NNS', 'O'),
#   ('of', 'IN', 'O'),
#   ('crops', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('state', 'NN', 'O'),
#   ('news', 'NN', 'O'),
#   ('agency', 'NN', 'O'),
#   ('KCNA', 'NNP', 'B-org'),
#   ('reported', 'VBD', 'O'),
#   ('the', 'DT', 'O'),
#   ('damage', 'NN', 'O'),
#   ('Monday', 'NNP', 'B-tim'),
#   ('.', '.', 'O')],
#  [('It', 'PRP', 'O'),
#   ('says', 'VBZ', 'O'),
#   ('the', 'DT', 'O'),
#   ('floods', 'NNS', 'O'),
#   ('also', 'RB', 'O'),
#   ('destroyed', 'VBD', 'O'),
#   ('or', 'CC', 'O'),
#   ('damaged', 'VBD', 'O'),
#   ('8,000', 'CD', 'O'),
#   ('public', 'JJ', 'O'),
#   ('buildings', 'NNS', 'O'),
#   ('and', 'CC', 'O'),
#   ('washed', 'VBD', 'O'),
#   ('out', 'RP', 'O'),
#   ('roads', 'NNS', 'O'),
#   (',', ',', 'O'),
#   ('bridges', 'NNS', 'O'),
#   ('and', 'CC', 'O'),
#   ('railways', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('report', 'NN', 'O'),
#   ('did', 'VBD', 'O'),
#   ('not', 'RB', 'O'),
#   ('mention', 'VB', 'O'),
#   ('any', 'DT', 'O'),
#   ('deaths', 'NNS', 'O'),
#   ('or', 'CC', 'O'),
#   ('injuries', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('Most', 'JJS', 'O'),
#   ('of', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('heavy', 'JJ', 'O'),
#   ('rains', 'NNS', 'O'),
#   ('and', 'CC', 'O'),
#   ('flooding', 'NN', 'O'),
#   ('occurred', 'VBD', 'O'),
#   ('in', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('southwestern', 'JJ', 'O'),
#   ('part', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('country', 'NN', 'O'),
#   (',', ',', 'O'),
#   ('including', 'VBG', 'O'),
#   ('the', 'DT', 'O'),
#   ('capital', 'NN', 'O'),
#   (',', ',', 'O'),
#   ('Pyongyang', 'NNP', 'B-geo'),
#   ('.', '.', 'O')],
#  [('Last', 'JJ', 'O'),
#   ('month', 'NN', 'O'),
#   (',', ',', 'O'),
#   ('severe', 'JJ', 'O'),
#   ('flooding', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('North', 'NNP', 'B-geo'),
#   ('Korea', 'NNP', 'I-geo'),
#   ('left', 'VBD', 'O'),
#   ('600', 'CD', 'O'),
#   ('people', 'NNS', 'O'),
#   ('dead', 'JJ', 'O'),
#   ('or', 'CC', 'O'),
#   ('missing', 'JJ', 'O'),
#   (',', ',', 'O'),
#   ('and', 'CC', 'O'),
#   ('displaced', 'VBD', 'O'),
#   ('more', 'JJR', 'O'),
#   ('than', 'IN', 'O'),
#   ('1,00,000', 'CD', 'O'),
#   ('others', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('A', 'DT', 'O'),
#   ('strong', 'JJ', 'O'),
#   ('earthquake', 'NN', 'O'),
#   ('under', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('ocean', 'NN', 'O'),
#   ('off', 'IN', 'O'),
#   ('Indonesia', 'NNP', 'B-org'),
#   ("'s", 'POS', 'I-org'),
#   ('Sumatra', 'NNP', 'I-org'),
#   ('and', 'CC', 'I-org'),
#   ('Nias', 'NNP', 'I-org'),
#   ('islands', 'NNS', 'I-org'),
#   ('has', 'VBZ', 'O'),
#   ('caused', 'VBN', 'O'),
#   ('some', 'DT', 'O'),
#   ('panic', 'NN', 'O'),
#   ('but', 'CC', 'O'),
#   ('no', 'DT', 'O'),
#   ('damage', 'NN', 'O'),
#   ('or', 'CC', 'O'),
#   ('injuries', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('U.S.', 'NNP', 'B-org'),
#   ('Geological', 'NNP', 'I-org'),
#   ('Survey', 'NNP', 'I-org'),
#   ('gave', 'VBD', 'O'),
#   ('a', 'DT', 'O'),
#   ('preliminary', 'JJ', 'O'),
#   ('estimate', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('strength', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('Tuesday', 'NNP', 'B-tim'),
#   ('morning', 'NN', 'I-tim'),
#   ('quake', 'NN', 'O'),
#   ('at', 'IN', 'O'),
#   ('6.7', 'CD', 'O'),
#   ('on', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('Richter', 'NNP', 'B-geo'),
#   ('scale', 'NN', 'O'),
#   (',', ',', 'O'),
#   ('and', 'CC', 'O'),
#   ('said', 'VBD', 'O'),
#   ('the', 'DT', 'O'),
#   ('epicenter', 'NN', 'O'),
#   ('was', 'VBD', 'O'),
#   ('close', 'RB', 'O'),
#   ('to', 'TO', 'O'),
#   ('the', 'DT', 'O'),
#   ('island', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('Nias', 'NNP', 'B-org'),
#   ('.', '.', 'O')],
#  [('Prime', 'JJ', 'O'),
#   ('Minister', 'NN', 'O'),
#   ('Geir', 'NNP', 'B-per'),
#   ('Haarde', 'NNP', 'I-per'),
#   ('has', 'VBZ', 'O'),
#   ('refused', 'VBN', 'O'),
#   ('to', 'TO', 'O'),
#   ('resign', 'VB', 'O'),
#   ('or', 'CC', 'O'),
#   ('call', 'VB', 'O'),
#   ('for', 'IN', 'O'),
#   ('early', 'JJ', 'O'),
#   ('elections', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('quake', 'NN', 'O'),
#   ('did', 'VBD', 'O'),
#   ('not', 'RB', 'O'),
#   ('cause', 'VB', 'O'),
#   ('a', 'DT', 'O'),
#   ('tsunami', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('An', 'DT', 'O'),
#   ('earthquake', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('late', 'JJ', 'O'),
#   ('March', 'NNP', 'B-tim'),
#   ('killed', 'VBD', 'O'),
#   ('more', 'JJR', 'O'),
#   ('than', 'IN', 'O'),
#   ('900', 'CD', 'O'),
#   ('people', 'NNS', 'O'),
#   ('on', 'IN', 'O'),
#   ('Nias', 'NNP', 'B-org'),
#   ('.', '.', 'O')],
#  [('Both', 'DT', 'O'),
#   ('Sumatra', 'NNP', 'B-org'),
#   ('and', 'CC', 'O'),
#   ('Nias', 'NNP', 'B-org'),
#   ('have', 'VBP', 'O'),
#   ('experienced', 'VBN', 'O'),
#   ('countless', 'JJ', 'O'),
#   ('earthquakes', 'NNS', 'O'),
#   ('since', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('massive', 'JJ', 'O'),
#   ('tsunami-producing', 'JJ', 'O'),
#   ('quake', 'NN', 'O'),
#   ('on', 'IN', 'O'),
#   ('December', 'NNP', 'B-tim'),
#   ('26', 'CD', 'I-tim'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('latest', 'JJS', 'O'),
#   ('official', 'NN', 'O'),
#   ('death', 'NN', 'O'),
#   ('toll', 'NN', 'O'),
#   ('from', 'IN', 'O'),
#   ('that', 'DT', 'O'),
#   ('tragedy', 'NN', 'O'),
#   ('stands', 'VBZ', 'O'),
#   ('at', 'IN', 'O'),
#   ('some', 'DT', 'O'),
#   ('1,76,000', 'CD', 'O'),
#   ('people', 'NNS', 'O'),
#   ('killed', 'VBN', 'O'),
#   ('-', 'IN', 'O'),
#   ('1,28,000', 'CD', 'O'),
#   ('of', 'IN', 'O'),
#   ('them', 'PRP', 'O'),
#   ('in', 'IN', 'O'),
#   ('Indonesia', 'NNP', 'B-geo'),
#   ('.', '.', 'O')],
#  [('Nearly', 'RB', 'O'),
#   ('50,000', 'CD', 'O'),
#   ('people', 'NNS', 'O'),
#   ('are', 'VBP', 'O'),
#   ('still', 'RB', 'O'),
#   ('listed', 'VBN', 'O'),
#   ('as', 'IN', 'O'),
#   ('missing', 'VBG', 'O'),
#   (',', ',', 'O'),
#   ('but', 'CC', 'O'),
#   ('most', 'JJS', 'O'),
#   ('of', 'IN', 'O'),
#   ('them', 'PRP', 'O'),
#   ('are', 'VBP', 'O'),
#   ('feared', 'VBN', 'O'),
#   ('dead', 'JJ', 'O'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('U.S.', 'NNP', 'B-geo'),
#   ('rap', 'NN', 'O'),
#   ('star', 'NN', 'O'),
#   ('Snoop', 'NNP', 'B-per'),
#   ('Dogg', 'NNP', 'I-per'),
#   ('and', 'CC', 'O'),
#   ('five', 'CD', 'O'),
#   ('of', 'IN', 'O'),
#   ('his', 'PRP$', 'O'),
#   ('associates', 'NNS', 'O'),
#   ('have', 'VBP', 'O'),
#   ('been', 'VBN', 'O'),
#   ('arrested', 'VBN', 'O'),
#   ('in', 'IN', 'O'),
#   ('Britain', 'NNP', 'B-geo'),
#   ('after', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('disturbance', 'NN', 'O'),
#   ('at', 'IN', 'O'),
#   ('London', 'NNP', 'B-geo'),
#   ("'s", 'POS', 'O'),
#   ('Heathrow', 'NNP', 'B-geo'),
#   ('Airport', 'NNP', 'I-geo'),
#   ('.', '.', 'O')],
#  [('Police', 'NNS', 'O'),
#   ('told', 'VBD', 'O'),
#   ('British', 'JJ', 'B-gpe'),
#   ('media', 'NNS', 'O'),
#   ('that', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('musician', 'NN', 'O'),
#   (',', ',', 'O'),
#   ('who', 'WP', 'O'),
#   ('was', 'VBD', 'O'),
#   ('born', 'VBN', 'O'),
#   ('with', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('name', 'NN', 'O'),
#   ('Calvin', 'NNP', 'B-per'),
#   ('Broadus', 'NNP', 'I-per'),
#   (',', ',', 'O'),
#   ('and', 'CC', 'O'),
#   ('members', 'NNS', 'O'),
#   ('of', 'IN', 'O'),
#   ('his', 'PRP$', 'O'),
#   ('entourage', 'NN', 'O'),
#   ('were', 'VBD', 'O'),
#   ('being', 'VBG', 'O'),
#   ('held', 'VBN', 'O'),
#   ('on', 'IN', 'O'),
#   ('charges', 'NNS', 'O'),
#   ('of', 'IN', 'O'),
#   ('"', '``', 'O'),
#   ('violent', 'JJ', 'O'),
#   ('disorder', 'NN', 'O'),
#   ('and', 'CC', 'O'),
#   ('affray', 'NN', 'O'),
#   ('.', '.', 'O'),
#   ('"', '``', 'O')],
#  [('The', 'DT', 'O'),
#   ('group', 'NN', 'O'),
#   ('was', 'VBD', 'O'),
#   ('waiting', 'VBG', 'O'),
#   ('for', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('flight', 'NN', 'O'),
#   ('to', 'TO', 'O'),
#   ('South', 'NNP', 'B-geo'),
#   ('Africa', 'NNP', 'I-geo'),
#   (',', ',', 'O'),
#   ('where', 'WRB', 'O'),
#   ('Snoop', 'NNP', 'B-per'),
#   ('Dogg', 'NNP', 'I-per'),
#   ('was', 'VBD', 'O'),
#   ('to', 'TO', 'O'),
#   ('perform', 'VB', 'O'),
#   ('in', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('concert', 'NN', 'O'),
#   ('Thursday', 'NNP', 'B-tim'),
#   (',', ',', 'O'),
#   ('when', 'WRB', 'O'),
#   ('it', 'PRP', 'O'),
#   ('was', 'VBD', 'O'),
#   ('denied', 'VBN', 'O'),
#   ('access', 'NN', 'O'),
#   ('to', 'TO', 'O'),
#   ('a', 'DT', 'O'),
#   ('first-class', 'JJ', 'O'),
#   ('lounge', 'NN', 'O'),
#   ('at', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('airport', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Police', 'NNS', 'O'),
#   ('said', 'VBD', 'O'),
#   ('members', 'NNS', 'O'),
#   ('of', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('group', 'NN', 'O'),
#   ('later', 'RB', 'O'),
#   ('threw', 'VBD', 'O'),
#   ('bottles', 'NNS', 'O'),
#   ('of', 'IN', 'O'),
#   ('whisky', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('duty-free', 'JJ', 'O'),
#   ('store', 'NN', 'O'),
#   ('and', 'CC', 'O'),
#   ('scuffled', 'VBD', 'O'),
#   ('with', 'IN', 'O'),
#   ('police', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Snoop', 'NNP', 'B-per'),
#   ('Dogg', 'NNP', 'I-per'),
#   ('is', 'VBZ', 'O'),
#   ('a', 'DT', 'O'),
#   ('former', 'JJ', 'O'),
#   ('member', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('street', 'NN', 'O'),
#   ('gang', 'NN', 'O'),
#   ('the', 'DT', 'O'),
#   ('Crips', 'NNS', 'B-org'),
#   (',', ',', 'O'),
#   ('from', 'IN', 'O'),
#   ('Southern', 'NNP', 'B-geo'),
#   ('California', 'NNP', 'I-geo'),
#   (',', ',', 'O'),
#   ('and', 'CC', 'O'),
#   ('many', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('his', 'PRP$', 'O'),
#   ('songs', 'NNS', 'O'),
#   ('reflect', 'VBP', 'O'),
#   ('the', 'DT', 'O'),
#   ('gritty', 'JJ', 'O'),
#   ('life', 'NN', 'O'),
#   ('on', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('streets', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('He', 'PRP', 'O'),
#   ('blames', 'VBZ', 'O'),
#   ('Iceland', 'NNP', 'B-org'),
#   ("'s", 'POS', 'O'),
#   ('economic', 'JJ', 'O'),
#   ('calamity', 'NN', 'O'),
#   ('on', 'IN', 'O'),
#   ('commercial', 'JJ', 'O'),
#   ('bankers', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('Afghan', 'JJ', 'B-gpe'),
#   ('President', 'NNP', 'B-per'),
#   ('Hamid', 'NNP', 'I-per'),
#   ('Karzai', 'NNP', 'I-per'),
#   ('says', 'VBZ', 'O'),
#   ('he', 'PRP', 'O'),
#   ('has', 'VBZ', 'O'),
#   ('fired', 'VBN', 'O'),
#   ('two', 'CD', 'O'),
#   ('"', '``', 'O'),
#   ('high-ranking', 'JJ', 'O'),
#   ('"', '``', 'O'),
#   ('Afghan', 'JJ', 'B-gpe'),
#   ('officials', 'NNS', 'O'),
#   ('who', 'WP', 'O'),
#   ('were', 'VBD', 'O'),
#   ('spying', 'VBG', 'O'),
#   ('for', 'IN', 'O'),
#   ('other', 'JJ', 'O'),
#   ('countries', 'NNS', 'O'),
#   (',', ',', 'O'),
#   ('and', 'CC', 'O'),
#   ('warns', 'VBZ', 'O'),
#   ('he', 'PRP', 'O'),
#   ('would', 'MD', 'O'),
#   ('not', 'RB', 'O'),
#   ('spare', 'VB', 'O'),
#   ('anyone', 'DT', 'O'),
#   ('who', 'WP', 'O'),
#   ('engages', 'VBZ', 'O'),
#   ('in', 'IN', 'O'),
#   ('such', 'JJ', 'O'),
#   ('activity', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Mr.', 'NNP', 'B-per'),
#   ('Karzai', 'NNP', 'I-per'),
#   ('made', 'VBD', 'O'),
#   ('the', 'DT', 'O'),
#   ('disclosure', 'NN', 'O'),
#   ('at', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('lunch', 'NN', 'O'),
#   ('meeting', 'NN', 'O'),
#   ('with', 'IN', 'O'),
#   ('newly', 'RB', 'O'),
#   ('sworn-in', 'JJ', 'O'),
#   ('parliament', 'NN', 'O'),
#   ('members', 'NNS', 'O'),
#   (',', ',', 'O'),
#   ('and', 'CC', 'O'),
#   ('did', 'VBD', 'O'),
#   ('not', 'RB', 'O'),
#   ('name', 'VB', 'O'),
#   ('the', 'DT', 'O'),
#   ('dismissed', 'VBN', 'O'),
#   ('officials', 'NNS', 'O'),
#   ('nor', 'CC', 'O'),
#   ('indicate', 'VBP', 'O'),
#   ('when', 'WRB', 'O'),
#   ('he', 'PRP', 'O'),
#   ('took', 'VBD', 'O'),
#   ('the', 'DT', 'O'),
#   ('action', 'NN', 'O'),
#   ('He', 'PRP', 'O'),
#   ('also', 'RB', 'O'),
#   ('did', 'VBD', 'O'),
#   ('not', 'RB', 'O'),
#   ('name', 'VB', 'O'),
#   ('the', 'DT', 'O'),
#   ('other', 'JJ', 'O'),
#   ('countries', 'NNS', 'O'),
#   ('involved', 'VBN', 'O'),
#   ('.', '.', 'O')],
#  [('Mr.', 'NNP', 'B-per'),
#   ('Karzai', 'NNP', 'I-per'),
#   ('said', 'VBD', 'O'),
#   ('he', 'PRP', 'O'),
#   ('had', 'VBD', 'O'),
#   ('strong', 'JJ', 'O'),
#   ('evidence', 'NN', 'O'),
#   ('against', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('two', 'CD', 'O'),
#   ('officials', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('But', 'CC', 'O'),
#   ('he', 'PRP', 'O'),
#   ('said', 'VBD', 'O'),
#   ('even', 'RB', 'O'),
#   ('if', 'IN', 'O'),
#   ('he', 'PRP', 'O'),
#   ('had', 'VBD', 'O'),
#   ('minor', 'JJ', 'O'),
#   ('evidence', 'NN', 'O'),
#   (',', ',', 'O'),
#   ('he', 'PRP', 'O'),
#   ('would', 'MD', 'O'),
#   ('have', 'VB', 'O'),
#   ('punished', 'VBN', 'O'),
#   ('them', 'PRP', 'O'),
#   ('.', '.', 'O')],
#  [('He', 'PRP', 'O'),
#   ('said', 'VBD', 'O'),
#   ('anyone', 'DT', 'O'),
#   ('found', 'VBD', 'O'),
#   ('spying', 'VBG', 'O'),
#   ('for', 'IN', 'O'),
#   ('foreign', 'JJ', 'O'),
#   ('countries', 'NNS', 'O'),
#   ('will', 'MD', 'O'),
#   ('be', 'VB', 'O'),
#   ('shown', 'VBN', 'O'),
#   ('on', 'IN', 'O'),
#   ('television', 'NN', 'O'),
#   (',', ',', 'O'),
#   ('and', 'CC', 'O'),
#   ('put', 'VBD', 'O'),
#   ('on', 'IN', 'O'),
#   ('trial', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Mr.', 'NNP', 'B-per'),
#   ('Karzai', 'NNP', 'I-per'),
#   ('has', 'VBZ', 'O'),
#   ('led', 'VBN', 'O'),
#   ('Afghanistan', 'NNP', 'B-gpe'),
#   ('since', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('Taleban', 'NNP', 'B-org'),
#   ('were', 'VBD', 'O'),
#   ('ousted', 'VBN', 'O'),
#   ('in', 'IN', 'O'),
#   ('late', 'JJ', 'O'),
#   ('2001', 'CD', 'B-tim'),
#   ('.', '.', 'O')],
#  [('He', 'PRP', 'O'),
#   ('won', 'VBD', 'O'),
#   ('a', 'DT', 'O'),
#   ('presidential', 'JJ', 'O'),
#   ('election', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('October', 'NNP', 'B-tim'),
#   ('2004', 'CD', 'I-tim'),
#   ('.', '.', 'O')],
#  [('And', 'CC', 'O'),
#   ('now', 'RB', 'O'),
#   ('the', 'DT', 'O'),
#   ('Taleban', 'NNP', 'B-org'),
#   ('are', 'VBP', 'O'),
#   ('waging', 'VBG', 'O'),
#   ('an', 'DT', 'O'),
#   ('insurgency', 'NN', 'O'),
#   ('against', 'IN', 'O'),
#   ('his', 'PRP$', 'O'),
#   ('administration', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('For', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('last', 'JJ', 'O'),
#   ('four', 'CD', 'B-tim'),
#   ('weeks', 'NNS', 'O'),
#   ('a', 'DT', 'O'),
#   ('team', 'NN', 'O'),
#   ('led', 'VBN', 'O'),
#   ('by', 'IN', 'O'),
#   ('former', 'JJ', 'O'),
#   ('UN', 'NNP', 'B-org'),
#   ('Secretary-General', 'NNP', 'I-org'),
#   ('Kofi', 'NNP', 'B-per'),
#   ('Annan', 'NNP', 'I-per'),
#   ('has', 'VBZ', 'O'),
#   ('been', 'VBN', 'O'),
#   ('trying', 'VBG', 'O'),
#   ('to', 'TO', 'O'),
#   ('broker', 'NN', 'O'),
#   ('a', 'DT', 'O'),
#   ('deal', 'NN', 'O'),
#   ('between', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('Kenyan', 'JJ', 'B-gpe'),
#   ('government', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('President', 'NNP', 'B-per'),
#   ('Mwai', 'NNP', 'I-per'),
#   ('Kibaki', 'NNP', 'I-per'),
#   ('and', 'CC', 'O'),
#   ('the', 'DT', 'O'),
#   ('opposition', 'NN', 'O'),
#   ('led', 'VBN', 'O'),
#   ('by', 'IN', 'O'),
#   ('Raila', 'NNP', 'B-org'),
#   ('Odinga', 'NNP', 'I-org'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('negotiations', 'NNS', 'O'),
#   ('have', 'VBP', 'O'),
#   ('concentrated', 'VBN', 'O'),
#   ('on', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('power', 'NN', 'O'),
#   ('sharing', 'NN', 'O'),
#   ('agreement', 'NN', 'O'),
#   ('and', 'CC', 'O'),
#   ('a', 'DT', 'O'),
#   ('transitional', 'JJ', 'O'),
#   ('arrangement', 'NN', 'O'),
#   ('leading', 'VBG', 'O'),
#   ('to', 'TO', 'O'),
#   ('new', 'JJ', 'O'),
#   ('elections', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('government', 'NN', 'O'),
#   ('was', 'VBD', 'O'),
#   ('forced', 'VBN', 'O'),
#   ('to', 'TO', 'O'),
#   ('ask', 'VB', 'O'),
#   ('the', 'DT', 'O'),
#   ('International', 'NNP', 'B-org'),
#   ('Monetary', 'NNP', 'I-org'),
#   ('Fund', 'NNP', 'I-org'),
#   ('and', 'CC', 'O'),
#   ('several', 'JJ', 'O'),
#   ('countries', 'NNS', 'O'),
#   ('for', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('multi-billion-dollar', 'JJ', 'O'),
#   ('loan', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('A', 'DT', 'O'),
#   ('recent', 'JJ', 'O'),
#   ('report', 'NN', 'O'),
#   ('by', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('international', 'JJ', 'O'),
#   ('crisis', 'NN', 'O'),
#   ('group', 'NN', 'O'),
#   ('says', 'VBZ', 'O'),
#   ('three', 'CD', 'O'),
#   ('complimentary', 'JJ', 'O'),
#   ('sets', 'NNS', 'O'),
#   ('of', 'IN', 'O'),
#   ('issues', 'NNS', 'O'),
#   ('must', 'MD', 'O'),
#   ('be', 'VB', 'O'),
#   ('addressed', 'VBN', 'O'),
#   ('to', 'TO', 'O'),
#   ('finalize', 'VB', 'O'),
#   ('a', 'DT', 'O'),
#   ('detailed', 'JJ', 'O'),
#   ('power', 'NN', 'O'),
#   ('sharing', 'NN', 'O'),
#   ('agreement', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Francois', 'NNP', 'B-per'),
#   ('Grignon', 'NNP', 'I-per'),
#   ('is', 'VBZ', 'O'),
#   ('director', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('Africa', 'NNP', 'B-geo'),
#   ('program', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('ICG', 'NNP', 'B-org'),
#   ('.', '.', 'O')],
#  [('In', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('telephone', 'NN', 'O'),
#   ('interview', 'NN', 'O'),
#   ('to', 'TO', 'O'),
#   ('discuss', 'VB', 'O'),
#   ('the', 'DT', 'O'),
#   ('issues', 'NNS', 'O'),
#   ('at', 'IN', 'O'),
#   ('stake', 'NN', 'O'),
#   (',', ',', 'O'),
#   ('he', 'PRP', 'O'),
#   ('told', 'VBD', 'O'),
#   ('VOA', 'NNP', 'B-org'),
#   ('reporter', 'NN', 'O'),
#   ('Akwei', 'NNP', 'B-per'),
#   ('Thompson', 'NNP', 'I-per'),
#   ('the', 'DT', 'O'),
#   ('opposition', 'NN', 'O'),
#   ('would', 'MD', 'O'),
#   ('demonstrate', 'VB', 'O'),
#   ('a', 'DT', 'O'),
#   ('stronger', 'JJR', 'O'),
#   ('political', 'JJ', 'O'),
#   ('will', 'NN', 'O'),
#   ('to', 'TO', 'O'),
#   ('tackle', 'VB', 'O'),
#   ('the', 'DT', 'O'),
#   ('task', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('legal', 'JJ', 'O'),
#   ('and', 'CC', 'O'),
#   ('constitutional', 'JJ', 'O'),
#   ('reform', 'NN', 'O'),
#   ('needed', 'VBN', 'O'),
#   ('during', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('transition', 'NN', 'O'),
#   ('period', 'NN', 'O'),
#   ('because', 'IN', 'O'),
#   ('\x85', ',', 'O'),
#   ('\x94', '``', 'O'),
#   ('the', 'DT', 'O'),
#   ('electoral', 'JJ', 'O'),
#   ('dispute', 'NN', 'O'),
#   ('left', 'VBD', 'O'),
#   ('them', 'PRP', 'O'),
#   ('out', 'RP', 'O'),
#   (',', ',', 'O'),
#   ('the', 'DT', 'O'),
#   ('losers', 'NNS', 'O'),
#   ('\x85', ',', 'O'),
#   ('.', '.', 'O'),
#   ('\x94', '``', 'O')],
#  [('President', 'NNP', 'B-per'),
#   ('Bush', 'NNP', 'I-per'),
#   ('has', 'VBZ', 'O'),
#   ('signed', 'VBN', 'O'),
#   ('legislation', 'NN', 'O'),
#   ('that', 'WDT', 'O'),
#   ('will', 'MD', 'O'),
#   ('require', 'VB', 'O'),
#   ('screening', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('all', 'DT', 'O'),
#   ('air', 'NN', 'O'),
#   ('and', 'CC', 'O'),
#   ('sea', 'NN', 'O'),
#   ('cargo', 'NN', 'O'),
#   (',', ',', 'O'),
#   ('and', 'CC', 'O'),
#   ('will', 'MD', 'O'),
#   ('provide', 'VB', 'O'),
#   ('more', 'JJR', 'O'),
#   ('money', 'NN', 'O'),
#   ('to', 'TO', 'O'),
#   ('cities', 'NNS', 'O'),
#   ('deemed', 'VBN', 'O'),
#   ('to', 'TO', 'O'),
#   ('be', 'VB', 'O'),
#   ('at', 'IN', 'O'),
#   ('high', 'JJ', 'O'),
#   ('risk', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('terrorist', 'JJ', 'O'),
#   ('attack', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('After', 'IN', 'O'),
#   ('signing', 'VBG', 'O'),
#   ('the', 'DT', 'O'),
#   ('bill', 'NN', 'O'),
#   ('Friday', 'NNP', 'B-tim'),
#   ('and', 'CC', 'O'),
#   ('meeting', 'NN', 'O'),
#   ('with', 'IN', 'O'),
#   ('his', 'PRP$', 'O'),
#   ('advisers', 'NNS', 'O'),
#   ('on', 'IN', 'O'),
#   ('counter-terrorism', 'NN', 'O'),
#   (',', ',', 'O'),
#   ('Mr.', 'NNP', 'B-per'),
#   ('Bush', 'NNP', 'I-per'),
#   ('said', 'VBD', 'O'),
#   ('his', 'PRP$', 'O'),
#   ('homeland', 'NN', 'O'),
#   ('security', 'NN', 'O'),
#   ('and', 'CC', 'O'),
#   ('counter-terrorism', 'NN', 'O'),
#   ('teams', 'NNS', 'O'),
#   ('are', 'VBP', 'O'),
#   ('doing', 'VBG', 'O'),
#   ('everything', 'DT', 'O'),
#   ('they', 'PRP', 'O'),
#   ('can', 'MD', 'O'),
#   ('to', 'TO', 'O'),
#   ('protect', 'VB', 'O'),
#   ('the', 'DT', 'O'),
#   ('country', 'NN', 'O'),
#   ('from', 'IN', 'O'),
#   ('what', 'WP', 'O'),
#   ('he', 'PRP', 'O'),
#   ('called', 'VBD', 'O'),
#   ('a', 'DT', 'O'),
#   ('"', '``', 'O'),
#   ('dangerous', 'JJ', 'O'),
#   ('enemy', 'NN', 'O'),
#   ('.', '.', 'O'),
#   ('"', '``', 'O')],
#  [('The', 'DT', 'O'),
#   ('new', 'JJ', 'O'),
#   ('measures', 'NNS', 'O'),
#   ('carry', 'VBP', 'O'),
#   ('out', 'RP', 'O'),
#   ('some', 'DT', 'O'),
#   ('recommendations', 'NNS', 'O'),
#   ('made', 'VBN', 'O'),
#   ('by', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('independent', 'JJ', 'O'),
#   ('commission', 'NN', 'O'),
#   ('that', 'WDT', 'O'),
#   ('investigated', 'VBD', 'O'),
#   ('the', 'DT', 'O'),
#   ('September', 'NNP', 'B-tim'),
#   ('11', 'CD', 'I-tim'),
#   (',', ',', 'I-tim'),
#   ('2001', 'CD', 'I-tim'),
#   ('attacks', 'NNS', 'O'),
#   ('on', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('United', 'NNP', 'B-geo'),
#   ('States', 'NNPS', 'I-geo'),
#   ('.', '.', 'O')],
#  [('Those', 'DT', 'O'),
#   ('include', 'VBP', 'O'),
#   ('a', 'DT', 'O'),
#   ('grant', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('$', '$', 'O'),
#   ('4', 'CD', 'O'),
#   ('billion', 'CD', 'O'),
#   ('to', 'TO', 'O'),
#   ('be', 'VB', 'O'),
#   ('given', 'VBN', 'O'),
#   ('to', 'TO', 'O'),
#   ('high-risk', 'JJ', 'O'),
#   ('cities', 'NNS', 'O'),
#   ('to', 'TO', 'O'),
#   ('upgrade', 'VB', 'O'),
#   ('transit', 'NN', 'O'),
#   ('security', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('They', 'PRP', 'O'),
#   ('also', 'RB', 'O'),
#   ('mandate', 'VB', 'O'),
#   ('screening', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('all', 'DT', 'O'),
#   ('U.S.-bound', 'JJ', 'O'),
#   ('cargo', 'NN', 'O'),
#   ('on', 'IN', 'O'),
#   ('planes', 'NNS', 'O'),
#   ('and', 'CC', 'O'),
#   ('ships', 'NNS', 'O'),
#   ('within', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('next', 'JJ', 'O'),
#   ('five', 'CD', 'B-tim'),
#   ('years', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('Burmese', 'JJ', 'B-gpe'),
#   ('democracy', 'NN', 'O'),
#   ('advocate', 'NN', 'O'),
#   ('Aung', 'NNP', 'O'),
#   ('San', 'NNP', 'B-geo'),
#   ('Suu', 'NNP', 'I-geo'),
#   ('Kyi', 'NNP', 'I-geo'),
#   ('is', 'VBZ', 'O'),
#   ('calling', 'VBG', 'O'),
#   ('on', 'IN', 'O'),
#   ('citizens', 'NNS', 'O'),
#   ('in', 'IN', 'O'),
#   ('her', 'PRP$', 'O'),
#   ('country', 'NN', 'O'),
#   ('to', 'TO', 'O'),
#   ('work', 'VB', 'O'),
#   ('toward', 'IN', 'O'),
#   ('national', 'JJ', 'O'),
#   ('reconciliation', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('new', 'JJ', 'B-tim'),
#   ('year', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('In', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('statement', 'NN', 'O'),
#   ('Friday', 'NNP', 'B-tim'),
#   (',', ',', 'O'),
#   ('she', 'PRP', 'O'),
#   ('asked', 'VBD', 'O'),
#   ('the', 'DT', 'O'),
#   ('Burmese', 'JJ', 'B-gpe'),
#   ('people', 'NNS', 'O'),
#   ('to', 'TO', 'O'),
#   ('"', '``', 'O'),
#   ('struggle', 'NN', 'O'),
#   ('together', 'RB', 'O'),
#   ('with', 'IN', 'O'),
#   ('new', 'JJ', 'O'),
#   ('strengths', 'NNS', 'O'),
#   (',', ',', 'O'),
#   ('new', 'JJ', 'O'),
#   ('force', 'NN', 'O'),
#   ('and', 'CC', 'O'),
#   ('new', 'JJ', 'O'),
#   ('words', 'NNS', 'O'),
#   ('"', '``', 'O'),
#   ('in', 'IN', 'O'),
#   ('2011', 'CD', 'B-tim'),
#   ('.', '.', 'O')],
#  [('Global', 'JJ', 'O'),
#   ('health', 'NN', 'O'),
#   ('experts', 'NNS', 'O'),
#   ('said', 'VBD', 'O'),
#   ('cancer', 'NN', 'O'),
#   ('will', 'MD', 'O'),
#   ('become', 'VB', 'O'),
#   ('the', 'DT', 'O'),
#   ('leading', 'VBG', 'O'),
#   ('cause', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('death', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('world', 'NN', 'O'),
#   ('by', 'IN', 'O'),
#   ('2010', 'CD', 'B-tim'),
#   (',', ',', 'O'),
#   ('overtaking', 'VBG', 'O'),
#   ('heart', 'NN', 'O'),
#   ('disease', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('65-year-old', 'JJ', 'O'),
#   ('advocate', 'NN', 'O'),
#   ('for', 'IN', 'O'),
#   ('democratic', 'JJ', 'O'),
#   ('reforms', 'NNS', 'O'),
#   ('in', 'IN', 'O'),
#   ('Burma', 'NNP', 'B-geo'),
#   ('was', 'VBD', 'O'),
#   ('released', 'VBN', 'O'),
#   ('after', 'IN', 'O'),
#   ('more', 'JJR', 'O'),
#   ('than', 'IN', 'O'),
#   ('seven', 'CD', 'O'),
#   ('years', 'NNS', 'O'),
#   ('of', 'IN', 'O'),
#   ('house', 'NN', 'O'),
#   ('arrest', 'NN', 'O'),
#   ('on', 'IN', 'O'),
#   ('November', 'NNP', 'B-tim'),
#   ('13', 'CD', 'I-tim'),
#   ('.', '.', 'O')],
#  [('That', 'DT', 'O'),
#   ('was', 'VBD', 'O'),
#   ('just', 'RB', 'O'),
#   ('days', 'NNS', 'O'),
#   ('after', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('country', 'NN', 'O'),
#   ("'s", 'POS', 'O'),
#   ('military', 'JJ', 'O'),
#   ('rulers', 'NNS', 'O'),
#   ('claimed', 'VBD', 'O'),
#   ('an', 'DT', 'O'),
#   ('overwhelming', 'JJ', 'O'),
#   ('victory', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('Burma', 'NNP', 'B-geo'),
#   ("'s", 'POS', 'O'),
#   ('widely', 'RB', 'O'),
#   ('criticized', 'VBN', 'O'),
#   ('first', 'JJ', 'O'),
#   ('election', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('two', 'CD', 'B-tim'),
#   ('decades', 'NNS', 'I-tim'),
#   ('.', '.', 'O')],
#  [('She', 'PRP', 'O'),
#   ('said', 'VBD', 'O'),
#   ('in', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('statement', 'NN', 'O'),
#   ('that', 'IN', 'O'),
#   ('Burmese', 'JJ', 'B-gpe'),
#   ('people', 'NNS', 'O'),
#   ('need', 'VBP', 'O'),
#   ('to', 'TO', 'O'),
#   ('establish', 'VB', 'O'),
#   ('political', 'JJ', 'O'),
#   ('and', 'CC', 'O'),
#   ('social', 'JJ', 'O'),
#   ('networks', 'NNS', 'O'),
#   ('to', 'TO', 'O'),
#   ('achieve', 'VB', 'O'),
#   ('"', '``', 'O'),
#   ('national', 'JJ', 'O'),
#   ('reconciliation', 'NN', 'O'),
#   ('as', 'RB', 'O'),
#   ('well', 'RB', 'O'),
#   ('as', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('truly', 'RB', 'O'),
#   ('united', 'JJ', 'O'),
#   ('spirit', 'NN', 'O'),
#   ('.', '.', 'O'),
#   ('"', '``', 'O')],
#  [('The', 'DT', 'O'),
#   ('United', 'NNP', 'B-geo'),
#   ('States', 'NNPS', 'I-geo'),
#   ('on', 'IN', 'O'),
#   ('Thursday', 'NNP', 'B-tim'),
#   ('again', 'RB', 'O'),
#   ('called', 'VBD', 'O'),
#   ('for', 'IN', 'O'),
#   ('Burma', 'NNP', 'B-geo'),
#   ("'s", 'POS', 'O'),
#   ('leaders', 'NNS', 'O'),
#   ('to', 'TO', 'O'),
#   ('free', 'VB', 'O'),
#   ('the', 'DT', 'O'),
#   ('more', 'JJR', 'O'),
#   ('than', 'IN', 'O'),
#   ('2,200', 'CD', 'O'),
#   ('political', 'JJ', 'O'),
#   ('prisoners', 'NNS', 'O'),
#   ('in', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('country', 'NN', 'O'),
#   ('and', 'CC', 'O'),
#   ('engage', 'VB', 'O'),
#   ('in', 'IN', 'O'),
#   ('talks', 'NNS', 'O'),
#   ('to', 'TO', 'O'),
#   ('promote', 'VB', 'O'),
#   ('democracy', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Former', 'JJ', 'O'),
#   ('U.S.', 'NNP', 'B-org'),
#   ('President', 'NNP', 'B-per'),
#   ('Bill', 'NNP', 'I-per'),
#   ('Clinton', 'NNP', 'I-per'),
#   ('has', 'VBZ', 'O'),
#   ('assembled', 'VBN', 'O'),
#   ('world', 'NN', 'O'),
#   ('leaders', 'NNS', 'O'),
#   (',', ',', 'O'),
#   ('activists', 'NNS', 'O'),
#   ('and', 'CC', 'O'),
#   ('academics', 'NNS', 'O'),
#   ('in', 'IN', 'O'),
#   ('New', 'NNP', 'B-geo'),
#   ('York', 'NNP', 'I-geo'),
#   ('to', 'TO', 'O'),
#   ('address', 'VB', 'O'),
#   ('the', 'DT', 'O'),
#   ('issues', 'NNS', 'O'),
#   ('of', 'IN', 'O'),
#   ('poverty', 'NN', 'O'),
#   (',', ',', 'O'),
#   ('global', 'JJ', 'O'),
#   ('warning', 'NN', 'O'),
#   ('and', 'CC', 'O'),
#   ('conflict', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Opening', 'VBG', 'O'),
#   ('Thursday', 'NNP', 'B-tim'),
#   (',', ',', 'O'),
#   ('the', 'DT', 'O'),
#   ('Clinton', 'NNP', 'B-per'),
#   ('Global', 'NNP', 'O'),
#   ('Initiative', 'NNP', 'O'),
#   ("'s", 'POS', 'O'),
#   ('conference', 'NN', 'O'),
#   ('coincides', 'NNS', 'O'),
#   ('with', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('Millennium', 'NNP', 'B-org'),
#   ('summit', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('United', 'NNP', 'B-org'),
#   ('Nations', 'NNP', 'I-org'),
#   ('General', 'NNP', 'I-org'),
#   ('Assembly', 'NNP', 'I-org'),
#   ('.', '.', 'O')],
#  [('Mr.', 'NNP', 'B-per'),
#   ('Clinton', 'NNP', 'I-per'),
#   ('says', 'VBZ', 'O'),
#   ('the', 'DT', 'O'),
#   ('focus', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('three-day', 'JJ', 'B-tim'),
#   ('conference', 'NN', 'O'),
#   ('is', 'VBZ', 'O'),
#   ('to', 'TO', 'O'),
#   ('secure', 'VB', 'O'),
#   ('concrete', 'JJ', 'O'),
#   ('pledges', 'NNS', 'O'),
#   ('from', 'IN', 'O'),
#   ('leaders', 'NNS', 'O'),
#   ('to', 'TO', 'O'),
#   ('address', 'VB', 'O'),
#   ('significant', 'JJ', 'O'),
#   ('problems', 'NNS', 'O'),
#   (',', ',', 'O'),
#   ('not', 'RB', 'O'),
#   ('to', 'TO', 'O'),
#   ('simply', 'RB', 'O'),
#   ('talk', 'VB', 'O'),
#   ('about', 'IN', 'O'),
#   ('them', 'PRP', 'O'),
#   ('.', '.', 'O')],
#  [('Organizers', 'NNS', 'O'),
#   ('say', 'VBP', 'O'),
#   ('the', 'DT', 'O'),
#   ('conference', 'NN', 'O'),
#   ('is', 'VBZ', 'O'),
#   ('different', 'JJ', 'O'),
#   ('from', 'IN', 'O'),
#   ('other', 'JJ', 'O'),
#   ('forums', 'NNS', 'O'),
#   ('because', 'IN', 'O'),
#   ('participants', 'NNS', 'O'),
#   ('are', 'VBP', 'O'),
#   ('required', 'VBN', 'O'),
#   ('to', 'TO', 'O'),
#   ('pledge', 'NN', 'O'),
#   ('to', 'TO', 'O'),
#   ('address', 'VB', 'O'),
#   ('issues', 'NNS', 'O'),
#   ('in', 'IN', 'O'),
#   ('concrete', 'JJ', 'O'),
#   ('ways', 'NNS', 'O'),
#   ('and', 'CC', 'O'),
#   ('to', 'TO', 'O'),
#   ('report', 'VB', 'O'),
#   ('back', 'RB', 'O'),
#   ('on', 'IN', 'O'),
#   ('their', 'PRP$', 'O'),
#   ('progress', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Expected', 'VBN', 'O'),
#   ('attendees', 'NNS', 'O'),
#   ('or', 'CC', 'O'),
#   ('speakers', 'NNS', 'O'),
#   ('include', 'VBP', 'O'),
#   ('British', 'JJ', 'B-gpe'),
#   ('Prime', 'NNP', 'B-per'),
#   ('Minister', 'NNP', 'I-per'),
#   ('Tony', 'NNP', 'I-per'),
#   ('Blair', 'NNP', 'I-per'),
#   (',', ',', 'O'),
#   ('U.N.', 'NNP', 'B-org'),
#   ('Secretary', 'NNP', 'B-per'),
#   ('General', 'NNP', 'B-org'),
#   ('Kofi', 'NNP', 'B-per'),
#   ('Annan', 'NNP', 'I-per'),
#   ('and', 'CC', 'O'),
#   ('Israel', 'NNP', 'B-geo'),
#   ("'s", 'POS', 'O'),
#   ('Deputy', 'NNP', 'O'),
#   ('Prime', 'NNP', 'B-per'),
#   ('Minister', 'NNP', 'I-per'),
#   ('Shimon', 'NNP', 'I-per'),
#   ('Peres', 'NNP', 'I-per'),
#   ('.', '.', 'O')],
#  [('Peruvian', 'JJ', 'B-gpe'),
#   ('election', 'NN', 'O'),
#   ('officials', 'NNS', 'O'),
#   ('say', 'VBP', 'O'),
#   ('the', 'DT', 'O'),
#   ('narrow', 'JJ', 'O'),
#   ('gap', 'NN', 'O'),
#   ('between', 'IN', 'O'),
#   ('two', 'CD', 'O'),
#   ('candidates', 'NNS', 'O'),
#   ('vying', 'VBG', 'O'),
#   ('for', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('second', 'JJ', 'O'),
#   ('spot', 'NN', 'O'),
#   ('on', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('ballot', 'NN', 'O'),
#   ('for', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('country', 'NN', 'O'),
#   ("'s", 'POS', 'O'),
#   ('run-off', 'JJ', 'O'),
#   ('presidential', 'JJ', 'O'),
#   ('election', 'NN', 'O'),
#   ('has', 'VBZ', 'O'),
#   ('tightened', 'VBN', 'O'),
#   ('further', 'RB', 'O'),
#   ('.', '.', 'O')],
#  [('A', 'DT', 'O'),
#   ('World', 'NNP', 'O'),
#   ('Health', 'NNP', 'O'),
#   ('Organization', 'NNP', 'O'),
#   ('report', 'NN', 'O'),
#   ('issued', 'VBN', 'O'),
#   ('Tuesday', 'NNP', 'B-tim'),
#   ('said', 'VBD', 'O'),
#   ('one', 'CD', 'O'),
#   ('factor', 'NN', 'O'),
#   ('behind', 'IN', 'O'),
#   ('cancer', 'NN', 'O'),
#   ("'s", 'POS', 'O'),
#   ('growing', 'VBG', 'O'),
#   ('deadliness', 'NN', 'O'),
#   ('is', 'VBZ', 'O'),
#   ('rising', 'VBG', 'O'),
#   ('cigarette', 'NN', 'O'),
#   ('smoking', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('developing', 'VBG', 'O'),
#   ('countries', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('Officials', 'NNS', 'O'),
#   ('said', 'VBD', 'O'),
#   ('Sunday', 'NNP', 'B-tim'),
#   ('former', 'JJ', 'O'),
#   ('center-left', 'NN', 'O'),
#   ('president', 'NN', 'O'),
#   ('Alan', 'NNP', 'B-per'),
#   ('Garcia', 'NNP', 'I-per'),
#   ('leads', 'VBZ', 'O'),
#   ('pro-business', 'JJ', 'O'),
#   ('congresswoman', 'NN', 'O'),
#   ('Lourdes', 'NNP', 'B-per'),
#   ('Flores', 'NNP', 'I-per'),
#   ('by', 'IN', 'O'),
#   ('less', 'JJR', 'O'),
#   ('than', 'IN', 'O'),
#   ('96,000', 'CD', 'O'),
#   ('votes', 'NNS', 'O'),
#   (',', ',', 'O'),
#   ('with', 'IN', 'O'),
#   ('nearly', 'RB', 'O'),
#   ('90', 'CD', 'O'),
#   ('percent', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('votes', 'NNS', 'O'),
#   ('counted', 'VBN', 'O'),
#   ('.', '.', 'O')],
#  [('Garcia', 'NNP', 'B-per'),
#   ('led', 'VBD', 'O'),
#   ('Flores', 'NNP', 'B-per'),
#   ('by', 'IN', 'O'),
#   ('nearly', 'RB', 'O'),
#   ('1,10,000', 'CD', 'O'),
#   ('votes', 'NNS', 'O'),
#   ('on', 'IN', 'O'),
#   ('Saturday', 'NNP', 'B-tim'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('surge', 'NN', 'O'),
#   ('by', 'IN', 'O'),
#   ('Flores', 'NNP', 'B-per'),
#   ('is', 'VBZ', 'O'),
#   ('attributed', 'VBN', 'O'),
#   ('to', 'TO', 'O'),
#   ('heavy', 'JJ', 'O'),
#   ('support', 'NN', 'O'),
#   ('among', 'IN', 'O'),
#   ('Peruvians', 'NNS', 'B-gpe'),
#   ('living', 'VBG', 'O'),
#   ('abroad', 'RB', 'O'),
#   ('whose', 'WP$', 'O'),
#   ('votes', 'NNS', 'O'),
#   ('are', 'VBP', 'O'),
#   ('apparently', 'RB', 'O'),
#   ('starting', 'VBG', 'O'),
#   ('to', 'TO', 'O'),
#   ('impact', 'VB', 'O'),
#   ('the', 'DT', 'O'),
#   ('election', 'NN', 'O'),
#   ('tally', 'RB', 'O'),
#   ('.', '.', 'O')],
#  [('Since', 'IN', 'O'),
#   ('no', 'DT', 'O'),
#   ('candidate', 'NN', 'O'),
# ...
#   ('in', 'IN', 'O'),
#   ('Sudan', 'NNP', 'B-geo'),
#   ("'s", 'POS', 'O'),
#   ('Darfur', 'NNP', 'B-geo'),
#   ('region', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Reuters', 'NNP', 'B-org'),
#   ('news', 'NN', 'O'),
#   ('agency', 'NN', 'O'),
#   ('reports', 'VBZ', 'O'),
#   ('the', 'DT', 'O'),
#   ('engineer', 'NN', 'O'),
#   ('was', 'VBD', 'O'),
#   ('in', 'IN', 'O'),
#   ('good', 'JJ', 'O'),
#   ('health', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('A', 'DT', 'O'),
#   ('Sudanese', 'JJ', 'B-gpe'),
#   ('army', 'NN', 'O'),
#   ('spokesman', 'NN', 'O'),
#   ('said', 'VBD', 'O'),
#   ('Wednesday', 'NNP', 'B-tim'),
#   ('he', 'PRP', 'O'),
#   ('had', 'VBD', 'O'),
#   ('information', 'NN', 'O'),
#   ('the', 'DT', 'O'),
#   ('engineer', 'NN', 'O'),
#   ('had', 'VBD', 'O'),
#   ('been', 'VBN', 'O'),
#   ('taken', 'VBN', 'O'),
#   ('hostage', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('neighboring', 'JJ', 'O'),
#   ('Chad', 'NNP', 'B-geo'),
#   ('.', '.', 'O')],
#  [('Last', 'JJ', 'O'),
#   ('month', 'NN', 'O'),
#   ('three', 'CD', 'O'),
#   ('Russian', 'JJ', 'B-gpe'),
#   ('pilots', 'NNS', 'O'),
#   ('were', 'VBD', 'O'),
#   ('kidnapped', 'VBN', 'O'),
#   ('in', 'IN', 'O'),
#   ('Sudan', 'NNP', 'B-geo'),
#   ("'s", 'POS', 'O'),
#   ('Darfur', 'NNP', 'B-org'),
#   ('region', 'NN', 'O'),
#   ('at', 'IN', 'O'),
#   ('gunpoint', 'NN', 'O'),
#   ('and', 'CC', 'O'),
#   ('held', 'VBN', 'O'),
#   ('for', 'IN', 'O'),
#   ('two', 'CD', 'B-tim'),
#   ('days', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('They', 'PRP', 'O'),
#   ('were', 'VBD', 'O'),
#   ('released', 'VBN', 'O'),
#   ('one', 'CD', 'O'),
#   ('day', 'NN', 'O'),
#   ('after', 'IN', 'O'),
#   ('an', 'DT', 'O'),
#   ('American', 'JJ', 'B-gpe'),
#   ('aid', 'NN', 'O'),
#   ('worker', 'NN', 'O'),
#   ('was', 'VBD', 'O'),
#   ('freed', 'VBN', 'O'),
#   ('in', 'IN', 'O'),
#   ('Darfur', 'NNP', 'B-geo'),
#   ('after', 'IN', 'O'),
#   ('being', 'VBG', 'O'),
#   ('held', 'VBN', 'O'),
#   ('captive', 'JJ', 'O'),
#   ('for', 'IN', 'O'),
#   ('more', 'JJR', 'O'),
#   ('than', 'IN', 'O'),
#   ('100', 'CD', 'O'),
#   ('days', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('India', 'NNP', 'B-geo'),
#   ('has', 'VBZ', 'O'),
#   ('announced', 'VBN', 'O'),
#   ('plans', 'NNS', 'O'),
#   ('to', 'TO', 'O'),
#   ('pay', 'VB', 'O'),
#   ('an', 'DT', 'O'),
#   ('additional', 'JJ', 'O'),
#   ('$', '$', 'O'),
#   ('160', 'CD', 'O'),
#   ('million', 'CD', 'O'),
#   ('to', 'TO', 'O'),
#   ('victims', 'NNS', 'O'),
#   ('of', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('1984', 'CD', 'B-tim'),
#   ('anti-Sikh', 'JJ', 'I-tim'),
#   ('riot', 'NN', 'I-tim'),
#   (',', ',', 'O'),
#   ('in', 'IN', 'O'),
#   ('which', 'WDT', 'O'),
#   ('more', 'JJR', 'O'),
#   ('than', 'IN', 'O'),
#   ('3,000', 'CD', 'O'),
#   ('Sikhs', 'NNS', 'B-gpe'),
#   ('were', 'VBD', 'O'),
#   ('killed', 'VBN', 'O'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('Indian', 'JJ', 'B-gpe'),
#   ('government', 'NN', 'O'),
#   ('said', 'VBD', 'O'),
#   ('Thursday', 'NNP', 'B-tim'),
#   ('the', 'DT', 'O'),
#   ('families', 'NNS', 'O'),
#   ('of', 'IN', 'O'),
#   ('those', 'DT', 'O'),
#   ('killed', 'VBN', 'O'),
#   ('will', 'MD', 'O'),
#   ('receive', 'VB', 'O'),
#   ('a', 'DT', 'O'),
#   ('total', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('nearly', 'RB', 'O'),
#   ('$', '$', 'O'),
#   ('7,800', 'CD', 'O'),
#   (',', ',', 'O'),
#   ('while', 'IN', 'O'),
#   ('those', 'DT', 'O'),
#   ('injured', 'VBN', 'O'),
#   ('in', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('riots', 'NNS', 'O'),
#   ('will', 'MD', 'O'),
#   ('receive', 'VB', 'O'),
#   ('a', 'DT', 'O'),
#   ('total', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('$', '$', 'O'),
#   ('2,800', 'CD', 'O'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('decision', 'NN', 'O'),
#   ('to', 'TO', 'O'),
#   ('increase', 'VB', 'O'),
#   ('the', 'DT', 'O'),
#   ('funds', 'NNS', 'O'),
#   ('given', 'VBN', 'O'),
#   ('to', 'TO', 'O'),
#   ('riot', 'NN', 'O'),
#   ('victims', 'NNS', 'O'),
#   ('came', 'VBD', 'O'),
#   ('after', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('report', 'NN', 'O'),
#   ('released', 'VBN', 'O'),
#   ('in', 'IN', 'O'),
#   ('August', 'NNP', 'B-tim'),
#   ('said', 'VBD', 'O'),
#   ('some', 'DT', 'O'),
#   ('Congress', 'NNP', 'B-org'),
#   ('party', 'NN', 'O'),
#   ('leaders', 'NNS', 'O'),
#   ('may', 'MD', 'O'),
#   ('have', 'VB', 'O'),
#   ('helped', 'VBN', 'O'),
#   ('incite', 'VB', 'O'),
#   ('the', 'DT', 'O'),
#   ('riots', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('riots', 'NNS', 'O'),
#   ('were', 'VBD', 'O'),
#   ('sparked', 'VBN', 'O'),
#   ('by', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('1984', 'CD', 'B-tim'),
#   ('assassination', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('Prime', 'NNP', 'B-per'),
#   ('Minister', 'NNP', 'I-per'),
#   ('Indira', 'NNP', 'I-per'),
#   ('Gandhi', 'NNP', 'I-per'),
#   (',', ',', 'O'),
#   ('by', 'IN', 'O'),
#   ('Sikh', 'NNP', 'B-org'),
#   ('members', 'NNS', 'O'),
#   ('of', 'IN', 'O'),
#   ('her', 'PRP$', 'O'),
#   ('security', 'NN', 'O'),
#   ('team', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Victims', 'NNS', 'O'),
#   ('and', 'CC', 'O'),
#   ('their', 'PRP$', 'O'),
#   ('families', 'NNS', 'O'),
#   ('say', 'VBP', 'O'),
#   ('the', 'DT', 'O'),
#   ('compensation', 'NN', 'O'),
#   ('is', 'VBZ', 'O'),
#   ('not', 'RB', 'O'),
#   ('enough', 'RB', 'O'),
#   (',', ',', 'O'),
#   ('and', 'CC', 'O'),
#   ('have', 'VBP', 'O'),
#   ('demanded', 'VBN', 'O'),
#   ('any', 'DT', 'O'),
#   ('politician', 'NN', 'O'),
#   ('who', 'WP', 'O'),
#   ('helped', 'VBD', 'O'),
#   ('incite', 'VB', 'O'),
#   ('the', 'DT', 'O'),
#   ('riot', 'NN', 'O'),
#   ('be', 'VB', 'O'),
#   ('brought', 'VBN', 'O'),
#   ('to', 'TO', 'O'),
#   ('justice', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Those', 'DT', 'O'),
#   ('quotas', 'NNS', 'O'),
#   ('filled', 'VBN', 'O'),
#   ('so', 'RB', 'O'),
#   ('quickly', 'RB', 'O'),
#   ('that', 'IN', 'O'),
#   ('millions', 'NNS', 'O'),
#   ('of', 'IN', 'O'),
#   ('items', 'NNS', 'O'),
#   ('of', 'IN', 'O'),
#   ('Chinese-made', 'JJ', 'O'),
#   ('clothing', 'NN', 'O'),
#   ('were', 'VBD', 'O'),
#   ('left', 'VBN', 'O'),
#   ('stranded', 'VBN', 'O'),
#   ('at', 'IN', 'O'),
#   ('customs', 'NNS', 'O'),
#   ('checkpoints', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('new', 'JJ', 'O'),
#   ('head', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('Palestinian', 'JJ', 'B-gpe'),
#   ('Fatah', 'NNP', 'O'),
#   ('movement', 'NN', 'O'),
#   ('has', 'VBZ', 'O'),
#   ('threatened', 'VBN', 'O'),
#   ('to', 'TO', 'O'),
#   ('expel', 'VB', 'O'),
#   ('popular', 'JJ', 'O'),
#   ('leader', 'NN', 'O'),
#   ('Marwan', 'NNP', 'B-per'),
#   ('Barghouti', 'NNP', 'I-per'),
#   ('unless', 'IN', 'O'),
#   ('he', 'PRP', 'O'),
#   ('withdraws', 'VBZ', 'O'),
#   ('from', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('Palestinian', 'JJ', 'B-gpe'),
#   ('presidential', 'JJ', 'O'),
#   ('race', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Barghouti', 'NNP', 'B-per'),
#   ('is', 'VBZ', 'O'),
#   ('seen', 'VBN', 'O'),
#   ('as', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('only', 'RB', 'O'),
#   ('serious', 'JJ', 'O'),
#   ('challenger', 'NN', 'O'),
#   ('to', 'TO', 'O'),
#   ('the', 'DT', 'O'),
#   ('official', 'JJ', 'O'),
#   ('Fatah', 'NNP', 'B-org'),
#   ('candidate', 'NN', 'O'),
#   (',', ',', 'O'),
#   ('former', 'JJ', 'O'),
#   ('prime', 'JJ', 'O'),
#   ('minister', 'NN', 'O'),
#   ('Mahmoud', 'NNP', 'B-per'),
#   ('Abbas', 'NNP', 'I-per'),
#   ('.', '.', 'O')],
#  [('Fatah', 'NNP', 'B-org'),
#   ('chief', 'NN', 'O'),
#   ('Faruq', 'NNP', 'B-per'),
#   ('Qaddumi', 'NNP', 'I-per'),
#   ('says', 'VBZ', 'O'),
#   ('any', 'DT', 'O'),
#   ('member', 'NN', 'O'),
#   ('who', 'WP', 'O'),
#   ('goes', 'VBZ', 'O'),
#   ('against', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('group', 'NN', 'O'),
#   ("'s", 'POS', 'O'),
#   ('decisions', 'NNS', 'O'),
#   ('should', 'MD', 'O'),
#   ('resign', 'VB', 'O'),
#   ('and', 'CC', 'O'),
#   ('have', 'VB', 'O'),
#   ('his', 'PRP$', 'O'),
#   ('membership', 'NN', 'O'),
#   ('cancelled', 'VBD', 'O'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('45-year-old', 'JJ', 'O'),
#   ('Barghouti', 'NNP', 'B-per'),
#   ('is', 'VBZ', 'O'),
#   ('currently', 'RB', 'O'),
#   ('serving', 'VBG', 'O'),
#   ('five', 'CD', 'O'),
#   ('life', 'NN', 'O'),
#   ('terms', 'NNS', 'O'),
#   ('in', 'IN', 'O'),
#   ('an', 'DT', 'O'),
#   ('Israeli', 'JJ', 'B-gpe'),
#   ('prison', 'NN', 'O'),
#   ('for', 'IN', 'O'),
#   ('planning', 'VBG', 'O'),
#   ('suicide', 'NN', 'O'),
#   ('attacks', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('Mr.', 'NNP', 'B-per'),
#   ('Barghouti', 'NNP', 'I-per'),
#   (',', ',', 'O'),
#   ('who', 'WP', 'O'),
#   ('has', 'VBZ', 'O'),
#   ('denied', 'VBN', 'O'),
#   ('involvement', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('attacks', 'NNS', 'O'),
#   (',', ',', 'O'),
#   ('filed', 'VBN', 'O'),
#   ('papers', 'NNS', 'O'),
#   ('for', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('January', 'NNP', 'B-tim'),
#   ('9th', 'CD', 'I-tim'),
#   ('presidential', 'JJ', 'O'),
#   ('race', 'NN', 'O'),
#   ('last', 'JJ', 'O'),
#   ('Wednesday', 'NNP', 'B-tim'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('winner', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('race', 'NN', 'O'),
#   ('will', 'MD', 'O'),
#   ('succeed', 'VB', 'O'),
#   ('the', 'DT', 'O'),
#   ('late', 'JJ', 'O'),
#   ('Yasser', 'NNP', 'B-org'),
#   ('Arafat', 'NNP', 'I-org'),
#   ('and', 'CC', 'O'),
#   ('lead', 'VB', 'O'),
#   ('the', 'DT', 'O'),
#   ('Palestinians', 'NNS', 'B-gpe'),
#   ('as', 'IN', 'O'),
#   ('world', 'NN', 'O'),
#   ('powers', 'NNS', 'O'),
#   ('try', 'VBP', 'O'),
#   ('to', 'TO', 'O'),
#   ('revive', 'VB', 'O'),
#   ('the', 'DT', 'O'),
#   ('Middle', 'NNP', 'B-geo'),
#   ('East', 'NNP', 'I-geo'),
#   ('peace', 'NN', 'O'),
#   ('process', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Israel', 'NNP', 'B-geo'),
#   ('says', 'VBZ', 'O'),
#   ('it', 'PRP', 'O'),
#   ('will', 'MD', 'O'),
#   ('not', 'RB', 'O'),
#   ('negotiate', 'VB', 'O'),
#   ('with', 'IN', 'O'),
#   ('Syria', 'NNP', 'B-geo'),
#   ('as', 'RB', 'O'),
#   ('long', 'RB', 'O'),
#   ('as', 'IN', 'O'),
#   ('Damascus', 'NNP', 'B-geo'),
#   ('supports', 'VBZ', 'O'),
#   ('terrorist', 'JJ', 'O'),
#   ('groups', 'NNS', 'O'),
#   (',', ',', 'O'),
#   ('brushing', 'VBG', 'O'),
#   ('off', 'RP', 'O'),
#   ('a', 'DT', 'O'),
#   ('Syrian', 'JJ', 'B-gpe'),
#   ('offer', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('peace', 'NN', 'O'),
#   ('talks', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('A', 'DT', 'O'),
#   ('spokeswoman', 'NN', 'O'),
#   ('for', 'IN', 'O'),
#   ('Israeli', 'JJ', 'B-gpe'),
#   ('Prime', 'NNP', 'B-per'),
#   ('Minister', 'NNP', 'O'),
#   ('Ehud', 'NNP', 'B-per'),
#   ('Olmert', 'NNP', 'I-per'),
#   ('Tuesday', 'NNP', 'B-tim'),
#   ('also', 'RB', 'O'),
#   ('criticized', 'VBD', 'O'),
#   ('Syria', 'NNP', 'B-geo'),
#   ('for', 'IN', 'O'),
#   ('pro-Hezbollah', 'JJ', 'O'),
#   ('statements', 'NNS', 'O'),
#   ('made', 'VBN', 'O'),
#   ('by', 'IN', 'O'),
#   ('its', 'PRP$', 'O'),
#   ('foreign', 'JJ', 'O'),
#   ('minister', 'NN', 'O'),
#   (',', ',', 'O'),
#   ('Walid', 'NNP', 'B-per'),
#   ('Moualem', 'NNP', 'I-per'),
#   ('during', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('month-long', 'JJ', 'O'),
#   ('Israel-Hezbollah', 'JJ', 'O'),
#   ('war', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Syria', 'NNP', 'B-geo'),
#   ('and', 'CC', 'O'),
#   ('Iran', 'NNP', 'B-geo'),
#   ('are', 'VBP', 'O'),
#   ('believed', 'VBN', 'O'),
#   ('to', 'TO', 'O'),
#   ('be', 'VB', 'O'),
#   ('key', 'JJ', 'O'),
#   ('suppliers', 'NNS', 'O'),
#   ('of', 'IN', 'O'),
#   ('weapons', 'NNS', 'O'),
#   ('and', 'CC', 'O'),
#   ('money', 'NN', 'O'),
#   ('to', 'TO', 'O'),
#   ('Hezbollah', 'NNP', 'B-org'),
#   ('.', '.', 'O')],
#  [('In', 'IN', 'O'),
#   ('an', 'DT', 'O'),
#   ('interview', 'NN', 'O'),
#   ('broadcast', 'NN', 'O'),
#   ('Monday', 'NNP', 'B-tim'),
#   (',', ',', 'O'),
#   ('Syrian', 'JJ', 'B-gpe'),
#   ('President', 'NNP', 'B-per'),
#   ('Bashar', 'NNP', 'I-per'),
#   ('al-Assad', 'NNP', 'I-per'),
#   ('said', 'VBD', 'O'),
#   ('he', 'PRP', 'O'),
#   ('is', 'VBZ', 'O'),
#   ('ready', 'JJ', 'O'),
#   ('to', 'TO', 'O'),
#   ('hold', 'VB', 'O'),
#   ('talks', 'NNS', 'O'),
#   ('with', 'IN', 'O'),
#   ('Israel', 'NNP', 'B-geo'),
#   ('but', 'CC', 'O'),
#   ('that', 'IN', 'O'),
#   ('an', 'DT', 'O'),
#   ('impartial', 'JJ', 'O'),
#   ('arbiter', 'NN', 'O'),
#   ('should', 'MD', 'O'),
#   ('mediate', 'VB', 'O'),
#   ('between', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('two', 'CD', 'O'),
#   ('sides', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('Mr.', 'NNP', 'B-per'),
#   ('Mandelson', 'NNP', 'I-per'),
#   ('Tuesday', 'NNP', 'B-tim'),
#   ('said', 'VBD', 'O'),
#   ('the', 'DT', 'O'),
#   ('economic', 'JJ', 'O'),
#   ('consequences', 'NNS', 'O'),
#   ('of', 'IN', 'O'),
#   ('not', 'RB', 'O'),
#   ('allowing', 'VBG', 'O'),
#   ('the', 'DT', 'O'),
#   ('goods', 'NNS', 'O'),
#   ('to', 'TO', 'O'),
#   ('enter', 'VB', 'O'),
#   ('Europe', 'NNP', 'B-geo'),
#   ('will', 'MD', 'O'),
#   ('be', 'VB', 'O'),
#   ('severe', 'JJ', 'O'),
#   ('for', 'IN', 'O'),
#   ('small', 'JJ', 'O'),
#   ('retailers', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('Syrian', 'JJ', 'B-gpe'),
#   ('leader', 'NN', 'O'),
#   ('said', 'VBD', 'O'),
#   ('he', 'PRP', 'O'),
#   ('doubts', 'VBZ', 'O'),
#   ('the', 'DT', 'O'),
#   ('U.S.', 'NNP', 'B-geo'),
#   ('can', 'MD', 'O'),
#   ('play', 'VB', 'O'),
#   ('that', 'DT', 'O'),
#   ('role', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('He', 'PRP', 'O'),
#   ('said', 'VBD', 'O'),
#   ('Washington', 'NNP', 'B-geo'),
#   ('lacks', 'VBZ', 'O'),
#   ('the', 'DT', 'O'),
#   ('will', 'NN', 'O'),
#   ('and', 'CC', 'O'),
#   ('the', 'DT', 'O'),
#   ('vision', 'NN', 'O'),
#   ('to', 'TO', 'O'),
#   ('pursue', 'VB', 'O'),
#   ('peace', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('Middle', 'NNP', 'B-geo'),
#   ('East', 'NNP', 'I-geo'),
#   ('.', '.', 'O')],
#  [('Talks', 'NNS', 'O'),
#   ('between', 'IN', 'O'),
#   ('Syria', 'NNP', 'B-geo'),
#   ('and', 'CC', 'O'),
#   ('Israel', 'NNP', 'B-geo'),
#   ('broke', 'VBD', 'O'),
#   ('down', 'RP', 'O'),
#   ('in', 'IN', 'O'),
#   ('2000', 'CD', 'B-tim'),
#   ('.', '.', 'O')],
#  [('Syria', 'NNP', 'B-geo'),
#   ('has', 'VBZ', 'O'),
#   ('demanded', 'VBN', 'O'),
#   ('that', 'IN', 'O'),
#   ('Israel', 'NNP', 'B-geo'),
#   ('return', 'VB', 'O'),
#   ('the', 'DT', 'O'),
#   ('entire', 'JJ', 'O'),
#   ('Golan', 'NNP', 'B-geo'),
#   ('Heights', 'NNP', 'I-geo'),
#   ('.', '.', 'O')],
#  [('Israel', 'NNP', 'B-geo'),
#   ('seized', 'VBD', 'O'),
#   ('the', 'DT', 'O'),
#   ('Golan', 'NNP', 'B-geo'),
#   ('Heights', 'NNPS', 'I-geo'),
#   ('in', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('1967', 'CD', 'B-tim'),
#   ('Six-Day', 'NNP', 'I-tim'),
#   ('War', 'NNP', 'I-tim'),
#   ('.', '.', 'O')],
#  [('Military', 'JJ', 'O'),
#   ('officials', 'NNS', 'O'),
#   ('in', 'IN', 'O'),
#   ('Iraq', 'NNP', 'B-geo'),
#   ('say', 'VBP', 'O'),
#   ('a', 'DT', 'O'),
#   ('U.S.', 'NNP', 'B-geo'),
#   ('soldier', 'NN', 'O'),
#   ('was', 'VBD', 'O'),
#   ('killed', 'VBN', 'O'),
#   ('and', 'CC', 'O'),
#   ('nine', 'CD', 'O'),
#   ('others', 'NNS', 'O'),
#   ('wounded', 'VBD', 'O'),
#   ('Saturday', 'NNP', 'B-tim'),
#   ('when', 'WRB', 'O'),
#   ('Iraqi', 'JJ', 'B-gpe'),
#   ('insurgents', 'NNS', 'O'),
#   ('attacked', 'VBD', 'O'),
#   ('an', 'DT', 'O'),
#   ('Army', 'NNP', 'B-org'),
#   ('patrol', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('central', 'JJ', 'O'),
#   ('Baghdad', 'NNP', 'B-geo'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('U.S.', 'NNP', 'B-geo'),
#   ('military', 'NN', 'O'),
#   ('says', 'VBZ', 'O'),
#   ('the', 'DT', 'O'),
#   ('unit', 'NN', 'O'),
#   ('came', 'VBD', 'O'),
#   ('under', 'IN', 'O'),
#   ('what', 'WP', 'O'),
#   ('it', 'PRP', 'O'),
#   ('called', 'VBD', 'O'),
#   ('a', 'DT', 'O'),
#   ('coordinated', 'JJ', 'O'),
#   ('attack', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('roadside', 'NN', 'O'),
#   ('bombs', 'NNS', 'O'),
#   (',', ',', 'O'),
#   ('small', 'JJ', 'O'),
#   ('arms', 'NNS', 'O'),
#   ('fire', 'NN', 'O'),
#   ('and', 'CC', 'O'),
#   ('rocket-propelled', 'JJ', 'O'),
#   ('grenades', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('Earlier', 'RB', 'O'),
#   (',', ',', 'O'),
#   ('Iraqi', 'JJ', 'B-gpe'),
#   ('insurgents', 'NNS', 'O'),
#   ('attacked', 'VBD', 'O'),
#   ('a', 'DT', 'O'),
#   ('police', 'NN', 'O'),
#   ('station', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('Azamiyah', 'NNP', 'B-geo'),
#   ('district', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('northwest', 'JJ', 'B-geo'),
#   ('Baghdad', 'NNP', 'I-geo'),
#   (',', ',', 'O'),
#   ('killing', 'VBG', 'O'),
#   ('at', 'IN', 'O'),
#   ('least', 'JJS', 'O'),
#   ('three', 'CD', 'O'),
#   ('policemen', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('Clashes', 'NNS', 'O'),
#   ('also', 'RB', 'O'),
#   ('broke', 'VBD', 'O'),
#   ('out', 'RP', 'O'),
#   ('between', 'IN', 'O'),
#   ('gunmen', 'NNS', 'O'),
#   ('and', 'CC', 'O'),
#   ('Iraqi', 'JJ', 'B-gpe'),
#   ('security', 'NN', 'O'),
#   ('forces', 'NNS', 'O'),
#   ('in', 'IN', 'O'),
#   ('Baghdad', 'NNP', 'B-geo'),
#   ("'s", 'POS', 'O'),
#   ('Amiriyah', 'NNP', 'B-geo'),
#   ('district', 'NN', 'O'),
#   ('.', '.', 'O')],
#  ...]

# %% [markdown]
# Let's see what we've got, by printing the sequences of words, POS and NER labels for a few sentences:

# %%
def pprint_sentence(sent):
    print(sent)
    
    for token in sent: print(token[0], end=" ") # Word
    print()

    for token in sent: print(token[1], end=" ") # POS
    print()

    for token in sent: print(token[2], end=" ") # Tag
    print("\n")

    return


pprint_sentence(sentences[0])
pprint_sentence(sentences[1])
pprint_sentence(sentences[2])
# Out:
# [('Thousands', 'NNS', 'O'), ('of', 'IN', 'O'), ('demonstrators', 'NNS', 'O'), ('have', 'VBP', 'O'), ('marched', 'VBN', 'O'), ('through', 'IN', 'O'), ('London', 'NNP', 'B-geo'), ('to', 'TO', 'O'), ('protest', 'VB', 'O'), ('the', 'DT', 'O'), ('war', 'NN', 'O'), ('in', 'IN', 'O'), ('Iraq', 'NNP', 'B-geo'), ('and', 'CC', 'O'), ('demand', 'VB', 'O'), ('the', 'DT', 'O'), ('withdrawal', 'NN', 'O'), ('of', 'IN', 'O'), ('British', 'JJ', 'B-gpe'), ('troops', 'NNS', 'O'), ('from', 'IN', 'O'), ('that', 'DT', 'O'), ('country', 'NN', 'O'), ('.', '.', 'O')]
# Thousands of demonstrators have marched through London to protest the war in Iraq and demand the withdrawal of British troops from that country .
# NNS IN NNS VBP VBN IN NNP TO VB DT NN IN NNP CC VB DT NN IN JJ NNS IN DT NN .
# O O O O O O B-geo O O O O O B-geo O O O O O B-gpe O O O O O
#
# [('Iranian', 'JJ', 'B-gpe'), ('officials', 'NNS', 'O'), ('say', 'VBP', 'O'), ('they', 'PRP', 'O'), ('expect', 'VBP', 'O'), ('to', 'TO', 'O'), ('get', 'VB', 'O'), ('access', 'NN', 'O'), ('to', 'TO', 'O'), ('sealed', 'JJ', 'O'), ('sensitive', 'JJ', 'O'), ('parts', 'NNS', 'O'), ('of', 'IN', 'O'), ('the', 'DT', 'O'), ('plant', 'NN', 'O'), ('Wednesday', 'NNP', 'B-tim'), (',', ',', 'O'), ('after', 'IN', 'O'), ('an', 'DT', 'O'), ('IAEA', 'NNP', 'B-org'), ('surveillance', 'NN', 'O'), ('system', 'NN', 'O'), ('begins', 'VBZ', 'O'), ('functioning', 'VBG', 'O'), ('.', '.', 'O')]
# Iranian officials say they expect to get access to sealed sensitive parts of the plant Wednesday , after an IAEA surveillance system begins functioning .
# JJ NNS VBP PRP VBP TO VB NN TO JJ JJ NNS IN DT NN NNP , IN DT NNP NN NN VBZ VBG .
# B-gpe O O O O O O O O O O O O O O B-tim O O O B-org O O O O O
#
# [('Helicopter', 'NN', 'O'), ('gunships', 'NNS', 'O'), ('Saturday', 'NNP', 'B-tim'), ('pounded', 'VBD', 'O'), ('militant', 'JJ', 'O'), ('hideouts', 'NNS', 'O'), ('in', 'IN', 'O'), ('the', 'DT', 'O'), ('Orakzai', 'NNP', 'B-geo'), ('tribal', 'JJ', 'O'), ('region', 'NN', 'O'), (',', ',', 'O'), ('where', 'WRB', 'O'), ('many', 'JJ', 'O'), ('Taliban', 'NNP', 'B-org'), ('militants', 'NNS', 'O'), ('are', 'VBP', 'O'), ('believed', 'VBN', 'O'), ('to', 'TO', 'O'), ('have', 'VB', 'O'), ('fled', 'VBN', 'O'), ('to', 'TO', 'O'), ('avoid', 'VB', 'O'), ('an', 'DT', 'O'), ('earlier', 'JJR', 'O'), ('military', 'JJ', 'O'), ('offensive', 'NN', 'O'), ('in', 'IN', 'O'), ('nearby', 'JJ', 'O'), ('South', 'NNP', 'B-geo'), ('Waziristan', 'NNP', 'I-geo'), ('.', '.', 'O')]
# Helicopter gunships Saturday pounded militant hideouts in the Orakzai tribal region , where many Taliban militants are believed to have fled to avoid an earlier military offensive in nearby South Waziristan .
# NN NNS NNP VBD JJ NNS IN DT NNP JJ NN , WRB JJ NNP NNS VBP VBN TO VB VBN TO VB DT JJR JJ NN IN JJ NNP NNP .
# O O B-tim O O O O O B-geo O O O O O B-org O O O O O O O O O O O O O O B-geo I-geo O

# %% [markdown]
# #### Feature extraction
#
# Next, we extract more features (word parts, simplified POS tags, lower/title/upper flags, features of nearby words) and convert them to sklearn-crfsuite format -- each sentence should be converted to a list of dicts. (The following code was taken from the [sklearn-crfsuite tutorial](https://sklearn-crfsuite.readthedocs.io/en/latest/tutorial.html).)

# %%
def word2features(sent, i):
    word = sent[i][0]
    postag = sent[i][1]

    features = {
        "bias": 1.0,
        "word.lower()": word.lower(),
        "word[-3:]": word[-3:],
        "word[-2:]": word[-2:],
        "word.isupper()": word.isupper(),
        "word.istitle()": word.istitle(),
        "word.isdigit()": word.isdigit(),
        "postag": postag,
        "postag[:2]": postag[:2],
    }
    if i > 0:
        word1 = sent[i - 1][0]
        postag1 = sent[i - 1][1]
        features.update(
            {
                "-1:word.lower()": word1.lower(),
                "-1:word.istitle()": word1.istitle(),
                "-1:word.isupper()": word1.isupper(),
                "-1:postag": postag1,
                "-1:postag[:2]": postag1[:2],
            }
        )
    else:
        features["BOS"] = True
    if i < len(sent) - 1:
        word1 = sent[i + 1][0]
        postag1 = sent[i + 1][1]
        features.update(
            {
                "+1:word.lower()": word1.lower(),
                "+1:word.istitle()": word1.istitle(),
                "+1:word.isupper()": word1.isupper(),
                "+1:postag": postag1,
                "+1:postag[:2]": postag1[:2],
            }
        )
    else:
        features["EOS"] = True

    return features


def sent2features(sent):
    return [word2features(sent, i) for i in range(len(sent))]


def sent2labels(sent):
    return [label for _, _, label in sent]


def sent2tokens(sent):
    return [token for token, _, _ in sent]

# %%
X = [sent2features(s) for s in sentences]
y = [sent2labels(s) for s in sentences]

# %% [markdown]
# Let's have a look at the features we get for a specific token:

# %%
pprint_sentence(sentences[0])
X[0][6]
# Out:
# [('Thousands', 'NNS', 'O'), ('of', 'IN', 'O'), ('demonstrators', 'NNS', 'O'), ('have', 'VBP', 'O'), ('marched', 'VBN', 'O'), ('through', 'IN', 'O'), ('London', 'NNP', 'B-geo'), ('to', 'TO', 'O'), ('protest', 'VB', 'O'), ('the', 'DT', 'O'), ('war', 'NN', 'O'), ('in', 'IN', 'O'), ('Iraq', 'NNP', 'B-geo'), ('and', 'CC', 'O'), ('demand', 'VB', 'O'), ('the', 'DT', 'O'), ('withdrawal', 'NN', 'O'), ('of', 'IN', 'O'), ('British', 'JJ', 'B-gpe'), ('troops', 'NNS', 'O'), ('from', 'IN', 'O'), ('that', 'DT', 'O'), ('country', 'NN', 'O'), ('.', '.', 'O')]
# Thousands of demonstrators have marched through London to protest the war in Iraq and demand the withdrawal of British troops from that country .
# NNS IN NNS VBP VBN IN NNP TO VB DT NN IN NNP CC VB DT NN IN JJ NNS IN DT NN .
# O O O O O O B-geo O O O O O B-geo O O O O O B-gpe O O O O O
# {'bias': 1.0,
#  'word.lower()': 'london',
#  'word[-3:]': 'don',
#  'word[-2:]': 'on',
#  'word.isupper()': False,
#  'word.istitle()': True,
#  'word.isdigit()': False,
#  'postag': 'NNP',
#  'postag[:2]': 'NN',
#  '-1:word.lower()': 'through',
#  '-1:word.istitle()': False,
#  '-1:word.isupper()': False,
#  '-1:postag': 'IN',
#  '-1:postag[:2]': 'IN',
#  '+1:word.lower()': 'to',
#  '+1:word.istitle()': False,
#  '+1:word.isupper()': False,
#  '+1:postag': 'TO',
#  '+1:postag[:2]': 'TO'}

# %% [markdown]
# We're good to go: let's split the data into training and test sets so that we can employ the CRF model.

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=0)

# %% [markdown]
# #### Training a CRF model
#
# We will make use of [sklearn-crfsuite](https://sklearn-crfsuite.readthedocs.io/en/latest/), which implements a CRF classifier.

# %%
import sklearn_crfsuite

crf = sklearn_crfsuite.CRF(algorithm="lbfgs", c1=0.1, c2=0.1, max_iterations=100, all_possible_transitions=True)

try:
    crf.fit(X_train, y_train)
except AttributeError:
    pass

y_pred = crf.predict(X_test)

# %%
from sklearn_crfsuite import metrics

print(f"Scores for the CRF model\n")
print(f"Accuracy: {metrics.flat_accuracy_score(y_test, y_pred)}")
print(f"Precision: {metrics.flat_precision_score(y_test, y_pred, average='macro')}")
print(f"Recall: {metrics.flat_recall_score(y_test, y_pred, average='macro')}")
print(f"F1 Score: {metrics.flat_f1_score(y_test, y_pred, average='macro')}")
# Out:
# Scores for the CRF model
#
# Accuracy: 0.9715637383249365
# Precision: 0.7731935336383909
# Recall: 0.6489404319203608
# F1 Score: 0.6911155780193032

# %% [markdown]
# What did the CRF classifier learn? Look at the output of the following code and interpret it.

# %%
from collections import Counter


def print_transitions(trans_features):
    for (label_from, label_to), weight in trans_features:
        print("%-6s -> %-7s %0.6f" % (label_from, label_to, weight))


print("Top likely transitions:")
print_transitions(Counter(crf.transition_features_).most_common(20))

print("\nTop unlikely transitions:")
print_transitions(Counter(crf.transition_features_).most_common()[-20:])
# Out:
# Top likely transitions:
# I-art  -> I-art   7.391358
# B-art  -> I-art   7.278202
# B-nat  -> I-nat   6.479038
# B-eve  -> I-eve   5.839108
# I-eve  -> I-eve   5.758097
# I-tim  -> I-tim   4.742140
# I-gpe  -> I-gpe   4.730158
# B-gpe  -> I-gpe   4.557278
# B-tim  -> I-tim   4.334957
# I-org  -> I-org   4.290097
# B-geo  -> I-geo   4.277619
# B-org  -> I-org   4.241753
# I-nat  -> I-nat   3.921685
# B-per  -> I-per   3.738044
# O      -> O       3.633986
# I-geo  -> I-geo   3.570474
# I-per  -> I-per   3.148476
# I-geo  -> B-art   1.880411
# O      -> B-per   1.824350
# B-org  -> B-art   1.528514
#
# Top unlikely transitions:
# I-org  -> B-org   -4.203153
# I-per  -> I-org   -4.227562
# B-org  -> I-geo   -4.255245
# I-org  -> I-geo   -4.298919
# B-geo  -> B-geo   -4.499268
# B-per  -> I-org   -4.704401
# B-geo  -> I-per   -4.778787
# B-tim  -> B-tim   -4.786172
# I-org  -> I-per   -4.928529
# B-geo  -> I-org   -5.109382
# B-org  -> I-per   -5.115562
# B-gpe  -> I-geo   -5.174884
# B-gpe  -> I-org   -5.675065
# I-per  -> B-per   -5.787749
# B-gpe  -> B-gpe   -5.939528
# O      -> I-per   -6.344294
# O      -> I-tim   -6.991131
# O      -> I-org   -7.414431
# O      -> I-geo   -7.802651
# B-per  -> B-per   -10.779160

# %% [markdown]
# Checking state features:

# %%
def print_state_features(state_features):
    for (attr, label), weight in state_features:
        print("%0.6f %-8s %s" % (weight, label, attr))


print("Top positive:")
print_state_features(Counter(crf.state_features_).most_common(20))

print("\nTop negative:")
print_state_features(Counter(crf.state_features_).most_common()[-20:])
# Out:
# Top positive:
# 7.845206 O        word.lower():last
# 7.786359 O        word.lower():month
# 7.580241 B-per    word.lower():vice
# 7.133286 B-org    word.lower():philippine
# 7.017612 B-tim    word.lower():multi-candidate
# 6.509159 B-gpe    word.lower():afghan
# 6.494892 B-gpe    word.lower():nepal
# 6.474656 B-tim    word.lower():2000
# 6.408125 B-gpe    word.lower():niger
# 6.340409 B-gpe    word.lower():german
# 6.220968 B-per    word.lower():obama
# 6.020412 B-tim    word.lower():february
# 5.957609 B-tim    word.lower():january
# 5.838123 B-org    word.lower():al-qaida
# 5.836919 B-org    word.lower():mid-march
# 5.777816 B-geo    word.lower():mid-march
# 5.750286 O        word.lower():chairman
# 5.706728 B-nat    word.lower():katrina
# 5.662584 O        BOS
# 5.659179 I-gpe    +1:word.lower():mayor
#
# Top negative:
# -3.604030 O        postag:NNP
# -3.650103 O        word[-3:]:1st
# -3.667834 O        word.lower():one-fourth
# -3.669180 O        +1:word.lower():ms.
# -3.681832 I-org    word.lower():secretary
# -3.710592 O        +1:word.lower():next
# -3.737056 O        word.lower():westerners
# -3.751114 O        word.lower():re-establishment
# -3.773720 O        word.lower():three-year
# -3.774647 O        +1:word.lower():months
# -3.897074 O        +1:word.lower():last
# -3.977821 O        +1:word.lower():year
# -3.991292 O        +1:word.lower():years
# -4.032212 B-gpe    word.lower():european
# -4.378263 O        word.lower():morning
# -4.411121 O        word.lower():multi-party
# -4.608025 O        word.lower():afternoon
# -4.608862 B-geo    word[-3:]:The
# -4.992223 O        word[-2:]:0s
# -5.020282 O        word.lower():summer

# %% [markdown]
# Using [ELI5](https://eli5.readthedocs.io/en/latest/index.html) we can visualize the CRF model weights (for state transitions and feature importance):

# %%
import eli5

eli5.show_weights(crf, top=10)

# %%
eli5.show_weights(crf, top=10, targets=["O", "B-org", "I-per"])

# %%
eli5.show_weights(crf, top=10, feature_re="^word\.is", horizontal_layout=False, show=["targets"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/margarida/Documents/m.eic/pln/notebooks/08-sequence-labeling-training_.ipynb Cell 57 in 1
# ----> <a href='vscode-notebook-cell:/home/margarida/Documents/m.eic/pln/notebooks/08-sequence-labeling-training_.ipynb#Y106sZmlsZQ%3D%3D?line=0'>1</a> eli5.show_weights(
#       <a href='vscode-notebook-cell:/home/margarida/Documents/m.eic/pln/notebooks/08-sequence-labeling-training_.ipynb#Y106sZmlsZQ%3D%3D?line=1'>2</a>     crf, top=10, feature_re="^word\.is", horizontal_layout=False, show=["targets"]
#       <a href='vscode-notebook-cell:/home/margarida/Documents/m.eic/pln/notebooks/08-sequence-labeling-training_.ipynb#Y106sZmlsZQ%3D%3D?line=2'>3</a> )
#
# File ~/.local/lib/python3.11/site-packages/eli5/ipython.py:130, in show_weights(estimator, **kwargs)
#      29 """ Return an explanation of estimator parameters (weights)
#      30 as an IPython.display.HTML object. Use this function
#      31 to show classifier weights in IPython.
#    (...)
#     127
#     128 """
#     129 format_kwargs, explain_kwargs = _split_kwargs(kwargs)
# --> 130 expl = explain_weights(estimator, **explain_kwargs)
#     131 _set_html_kwargs_defaults(format_kwargs)
#     132 html = format_as_html(expl, **format_kwargs)
#
# File /usr/lib64/python3.11/functools.py:909, in singledispatch.<locals>.wrapper(*args, **kw)
#     905 if not args:
#     906     raise TypeError(f'{funcname} requires at least '
#     907                     '1 positional argument')
# --> 909 return dispatch(args[0].__class__)(*args, **kw)
#
# File ~/.local/lib/python3.11/site-packages/eli5/sklearn_crfsuite/explain_weights.py:63, in explain_weights_sklearn_crfsuite(crf, top, target_names, targets, feature_re, feature_filter)
#      48 indices, names = zip(*display_names)
#      49 transition_coef = filter_transition_coefs(transition_coef, indices)
#      51 return Explanation(
#      52     targets=[
#      53         TargetExplanation(
#      54             target=label,
#      55             feature_weights=_features(label_id)
#      56         )
#      57         for label_id, label in zip(indices, names)
#      58     ],
#      59     transition_features=TransitionFeatureWeights(
#      60         class_names=names,
#      61         coef=transition_coef,
#      62     ),
# ---> 63     estimator=repr(crf),
#      64     method='CRF',
#      65 )
#
# File ~/.local/lib/python3.11/site-packages/sklearn/base.py:279, in BaseEstimator.__repr__(self, N_CHAR_MAX)
#     271 # use ellipsis for sequences with a lot of elements
#     272 pp = _EstimatorPrettyPrinter(
#     273     compact=True,
#     274     indent=1,
#     275     indent_at_name=True,
#     276     n_max_elements_to_show=N_MAX_ELEMENTS_TO_SHOW,
#     277 )
# --> 279 repr_ = pp.pformat(self)
#     281 # Use bruteforce ellipsis when there are a lot of non-blank characters
#     282 n_nonblank = len("".join(repr_.split()))
#
# File /usr/lib64/python3.11/pprint.py:158, in PrettyPrinter.pformat(self, object)
#     156 def pformat(self, object):
#     157     sio = _StringIO()
# --> 158     self._format(object, sio, 0, 0, {}, 0)
#     159     return sio.getvalue()
#
# File /usr/lib64/python3.11/pprint.py:175, in PrettyPrinter._format(self, object, stream, indent, allowance, context, level)
#     173     self._readable = False
#     174     return
# --> 175 rep = self._repr(object, context, level)
#     176 max_width = self._width - indent - allowance
#     177 if len(rep) > max_width:
#
# File /usr/lib64/python3.11/pprint.py:455, in PrettyPrinter._repr(self, object, context, level)
#     454 def _repr(self, object, context, level):
# --> 455     repr, readable, recursive = self.format(object, context.copy(),
#     456                                             self._depth, level)
#     457     if not readable:
#     458         self._readable = False
#
# File ~/.local/lib/python3.11/site-packages/sklearn/utils/_pprint.py:189, in _EstimatorPrettyPrinter.format(self, object, context, maxlevels, level)
#     188 def format(self, object, context, maxlevels, level):
# --> 189     return _safe_repr(
#     190         object, context, maxlevels, level, changed_only=self._changed_only
#     191     )
#
# File ~/.local/lib/python3.11/site-packages/sklearn/utils/_pprint.py:440, in _safe_repr(object, context, maxlevels, level, changed_only)
#     438 recursive = False
#     439 if changed_only:
# --> 440     params = _changed_params(object)
#     441 else:
#     442     params = object.get_params(deep=False)
#
# File ~/.local/lib/python3.11/site-packages/sklearn/utils/_pprint.py:93, in _changed_params(estimator)
#      89 def _changed_params(estimator):
#      90     """Return dict (param_name: value) of parameters that were given to
#      91     estimator with non-default values."""
# ---> 93     params = estimator.get_params(deep=False)
#      94     init_func = getattr(estimator.__init__, "deprecated_original", estimator.__init__)
#      95     init_params = inspect.signature(init_func).parameters
#
# File ~/.local/lib/python3.11/site-packages/sklearn/base.py:211, in BaseEstimator.get_params(self, deep)
#     209 out = dict()
#     210 for key in self._get_param_names():
# --> 211     value = getattr(self, key)
#     212     if deep and hasattr(value, "get_params") and not isinstance(value, type):
#     213         deep_items = value.get_params().items()
#
# AttributeError: 'CRF' object has no attribute 'keep_tempfiles'
